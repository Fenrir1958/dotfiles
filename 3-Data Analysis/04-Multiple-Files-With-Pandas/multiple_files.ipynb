# %% [markdown]
# # Multiple files with `pandas`

# %%
import numpy as np
import pandas as pd
import matplotlib

# %% [markdown]
# ## Merge Practice

# %%
a_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Finland'],
    'Population (M)': [82.8, 67.2, 11.4, 5.5],
    'Capital': ['Berlin', 'Paris', 'Brussels', 'Helsinki']
})
a_df
# Out:
#    Country  Population (M)   Capital
# 0  Germany            82.8    Berlin
# 1   France            67.2     Paris
# 2  Belgium            11.4  Brussels
# 3  Finland             5.5  Helsinki

# %%
b_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Canada'],
    'HDI': [0.936, 0.901, 0.916, 0.926]
})
b_df
# Out:
#    Country    HDI
# 0  Germany  0.936
# 1   France  0.901
# 2  Belgium  0.916
# 3   Canada  0.926

# %% [markdown]
# ### Inner Merge Practice

# %%
inner_merged_df = a_df.merge(b_df)

inner_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult
result = ChallengeResult('inner_merge',
    inner_merged_shape=inner_merged_df.shape,
    inner_merged_nulls=sum(inner_merged_df.isnull().sum())
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-7.1.3, pluggy-1.0.0 -- /home/victor/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/victor/code/Fenrir1958/dotfiles/3-Data Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_inner_merge.py::TestInnerMerge::test_inner_merged_nulls PASSED      [ 50%]
# test_inner_merge.py::TestInnerMerge::test_inner_merged_shape PASSED      [100%]
#
# ============================== 2 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/inner_merge.pickle
#
# git commit -m 'Completed inner_merge step'
#
# git push origin master

# %% [markdown]
# ### Left Merge Practice

# %%
left_merged_df = a_df.merge(b_df,how='left')

left_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN

# %%
from nbresult import ChallengeResult
result = ChallengeResult('left_merge',
    left_merged_shape=left_merged_df.shape,
    left_merged_nulls=sum(left_merged_df.isnull().sum())
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-7.1.3, pluggy-1.0.0 -- /home/victor/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/victor/code/Fenrir1958/dotfiles/3-Data Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_left_merge.py::TestLeftMerge::test_left_merged_df_shape PASSED      [ 50%]
# test_left_merge.py::TestLeftMerge::test_left_merged_nulls PASSED         [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/left_merge.pickle
#
# git commit -m 'Completed left_merge step'
#
# git push origin master

# %% [markdown]
# ### Right Merge Practice

# %%
right_merged_df = a_df.merge(b_df,how='right')

right_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3   Canada             NaN       NaN  0.926

# %%
from nbresult import ChallengeResult
result = ChallengeResult('right_merge',
    right_merged_shape=right_merged_df.shape,
    right_merged_nulls=sum(right_merged_df.isnull().sum())
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-7.1.3, pluggy-1.0.0 -- /home/victor/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/victor/code/Fenrir1958/dotfiles/3-Data Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 0 items
#
# ============================ no tests ran in 0.01s =============================

# %% [markdown]
# ### Outer Merge Practice

# %%
outer_merged_df = a_df.merge(b_df,how='outer')

outer_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN
# 4   Canada             NaN       NaN  0.926

# %%
from nbresult import ChallengeResult
result = ChallengeResult('outer_merge',
    outer_merged_shape=outer_merged_df.shape,
    outer_merged_nulls=sum(outer_merged_df.isnull().sum())
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-7.1.3, pluggy-1.0.0 -- /home/victor/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/victor/code/Fenrir1958/dotfiles/3-Data Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_outer_merge.py::TestOuterMerge::test_outer_merged_df_shape PASSED   [ 50%]
# test_outer_merge.py::TestOuterMerge::test_outer_merged_nulls PASSED      [100%]
#
# ============================== 2 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/outer_merge.pickle
#
# git commit -m 'Completed outer_merge step'
#
# git push origin master

# %% [markdown]
# ## Join Practice

# %%
aa_df = a_df.set_index("Country")
aa_df
# Out:
#          Population (M)   Capital
# Country
# Germany            82.8    Berlin
# France             67.2     Paris
# Belgium            11.4  Brussels
# Finland             5.5  Helsinki

# %%
bb_df = b_df.set_index("Country")
bb_df
# Out:
#            HDI
# Country
# Germany  0.936
# France   0.901
# Belgium  0.916
# Canada   0.926

# %%
aa_df.join(bb_df)
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Finland             5.5  Helsinki    NaN

# %%
aa_df.join(bb_df, how='inner')
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916

# %%
aa_df.join(bb_df, how='right')
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Canada              NaN       NaN  0.926

# %%
aa_df.join(bb_df, how='outer')
# Out:
#          Population (M)   Capital    HDI
# Country
# Belgium            11.4  Brussels  0.916
# Canada              NaN       NaN  0.926
# Finland             5.5  Helsinki    NaN
# France             67.2     Paris  0.901
# Germany            82.8    Berlin  0.936

# %% [markdown]
# ## Concat Practice

# %%
concat_df = pd.concat([a_df, b_df], axis="index", sort=False)
concat_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin    NaN
# 1   France            67.2     Paris    NaN
# 2  Belgium            11.4  Brussels    NaN
# 3  Finland             5.5  Helsinki    NaN
# 0  Germany             NaN       NaN  0.936
# 1   France             NaN       NaN  0.901
# 2  Belgium             NaN       NaN  0.916
# 3   Canada             NaN       NaN  0.926

# %% [markdown]
# ## Olympic Sports and Medals, 1896-2014

# %%
file = "dictionary.csv"
countries_df = pd.read_csv(file, delimiter=",")

countries_df
# Out:
#              Country Code  Population  GDP per Capita
# 0        Afghanistan  AFG  32526562.0      594.323081
# 1            Albania  ALB   2889167.0     3945.217582
# 2            Algeria  ALG  39666519.0     4206.031232
# 3    American Samoa*  ASA     55538.0             NaN
# 4            Andorra  AND     70473.0             NaN
# ..               ...  ...         ...             ...
# 196          Vietnam  VIE  91703800.0     2111.138024
# 197  Virgin Islands*  ISV    103574.0             NaN
# 198            Yemen  YEM  26832215.0     1406.291651
# 199           Zambia  ZAM  16211767.0     1304.879014
# 200         Zimbabwe  ZIM  15602751.0      924.143819
#
# [201 rows x 4 columns]

# %%
file = "summer.csv"
summer_df = pd.read_csv(file, delimiter=",")

summer_df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
file = "winter.csv"
winter_df = pd.read_csv(file, delimiter=",")

winter_df
# Out:
#       Year      City     Sport Discipline               Athlete Country  \
# 0     1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA
# 1     1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA
# 2     1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA
# 3     1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA
# 4     1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI
# ...    ...       ...       ...        ...                   ...     ...
# 5765  2014     Sochi    Skiing  Snowboard          JONES, Jenny     GBR
# 5766  2014     Sochi    Skiing  Snowboard       ANDERSON, Jamie     USA
# 5767  2014     Sochi    Skiing  Snowboard    MALTAIS, Dominique     CAN
# 5768  2014     Sochi    Skiing  Snowboard          SAMKOVA, Eva     CZE
# 5769  2014     Sochi    Skiing  Snowboard      TRESPEUCH, Chloe     FRA
#
#      Gender            Event   Medal
# 0       Men  Military Patrol  Bronze
# 1       Men  Military Patrol  Bronze
# 2       Men  Military Patrol  Bronze
# 3       Men  Military Patrol  Bronze
# 4       Men  Military Patrol    Gold
# ...     ...              ...     ...
# 5765  Women       Slopestyle  Bronze
# 5766  Women       Slopestyle    Gold
# 5767  Women  Snowboard Cross  Silver
# 5768  Women  Snowboard Cross    Gold
# 5769  Women  Snowboard Cross  Bronze
#
# [5770 rows x 9 columns]

# %% [markdown]
# ### Combining The Data

# %%
summer_df.rename({'Country': 'Code'}, axis=1, inplace=True)

summer_df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Code Gender                       Event  \
# 0                  HAJOS, Alfred  HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto  AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios  GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis  GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon  GRE    Men  100M Freestyle For Sailors
# ...                          ...  ...    ...                         ...
# 31160         JANIKOWSKI, Damian  POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza  IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam  RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur  ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy  SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
winter_df.rename({'Country': 'Code'}, axis=1, inplace=True)

winter_df
# Out:
#       Year      City     Sport Discipline               Athlete Code Gender  \
# 0     1924  Chamonix  Biathlon   Biathlon           BERTHET, G.  FRA    Men
# 1     1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.  FRA    Men
# 2     1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice  FRA    Men
# 3     1924  Chamonix  Biathlon   Biathlon       VANDELLE, André  FRA    Men
# 4     1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf  SUI    Men
# ...    ...       ...       ...        ...                   ...  ...    ...
# 5765  2014     Sochi    Skiing  Snowboard          JONES, Jenny  GBR  Women
# 5766  2014     Sochi    Skiing  Snowboard       ANDERSON, Jamie  USA  Women
# 5767  2014     Sochi    Skiing  Snowboard    MALTAIS, Dominique  CAN  Women
# 5768  2014     Sochi    Skiing  Snowboard          SAMKOVA, Eva  CZE  Women
# 5769  2014     Sochi    Skiing  Snowboard      TRESPEUCH, Chloe  FRA  Women
#
#                 Event   Medal
# 0     Military Patrol  Bronze
# 1     Military Patrol  Bronze
# 2     Military Patrol  Bronze
# 3     Military Patrol  Bronze
# 4     Military Patrol    Gold
# ...               ...     ...
# 5765       Slopestyle  Bronze
# 5766       Slopestyle    Gold
# 5767  Snowboard Cross  Silver
# 5768  Snowboard Cross    Gold
# 5769  Snowboard Cross  Bronze
#
# [5770 rows x 9 columns]

# %%
summer_countries_df = countries_df.merge(summer_df)

summer_countries_df['Season'] = "Summer"

summer_countries_df
# Out:
#            Country Code  Population  GDP per Capita  Year         City  \
# 0      Afghanistan  AFG  32526562.0      594.323081  2008      Beijing
# 1      Afghanistan  AFG  32526562.0      594.323081  2012       London
# 2          Algeria  ALG  39666519.0     4206.031232  1984  Los Angeles
# 3          Algeria  ALG  39666519.0     4206.031232  1984  Los Angeles
# 4          Algeria  ALG  39666519.0     4206.031232  1992    Barcelona
# ...            ...  ...         ...             ...   ...          ...
# 25737     Zimbabwe  ZIM  15602751.0      924.143819  2004       Athens
# 25738     Zimbabwe  ZIM  15602751.0      924.143819  2008      Beijing
# 25739     Zimbabwe  ZIM  15602751.0      924.143819  2008      Beijing
# 25740     Zimbabwe  ZIM  15602751.0      924.143819  2008      Beijing
# 25741     Zimbabwe  ZIM  15602751.0      924.143819  2008      Beijing
#
#            Sport Discipline             Athlete Gender  \
# 0      Taekwondo  Taekwondo    NIKPAI, Rohullah    Men
# 1      Taekwondo  Taekwondo    NIKPAI, Rohullah    Men
# 2         Boxing     Boxing      ZAOUI, Mohamed    Men
# 3         Boxing     Boxing    MOUSSA, Mustapha    Men
# 4      Athletics  Athletics  BOULMERKA, Hassiba  Women
# ...          ...        ...                 ...    ...
# 25737   Aquatics   Swimming    COVENTRY, Kirsty  Women
# 25738   Aquatics   Swimming    COVENTRY, Kirsty  Women
# 25739   Aquatics   Swimming    COVENTRY, Kirsty  Women
# 25740   Aquatics   Swimming    COVENTRY, Kirsty  Women
# 25741   Aquatics   Swimming    COVENTRY, Kirsty  Women
#
#                                Event   Medal  Season
# 0                            - 58 KG  Bronze  Summer
# 1                         58 - 68 KG  Bronze  Summer
# 2                            71-75KG  Bronze  Summer
# 3      75 - 81KG (Light-Heavyweight)  Bronze  Summer
# 4                              1500M    Gold  Summer
# ...                              ...     ...     ...
# 25737         200M Individual Medley  Bronze  Summer
# 25738                100M Backstroke  Silver  Summer
# 25739                200M Backstroke    Gold  Summer
# 25740         200M Individual Medley  Silver  Summer
# 25741         400M Individual Medley  Silver  Summer
#
# [25742 rows x 13 columns]

# %%
winter_countries_df = countries_df.merge(winter_df)

winter_countries_df['Season'] = "Winter"

winter_countries_df
# Out:
#             Country Code   Population  GDP per Capita  Year         City  \
# 0         Australia  AUS   23781169.0    56310.962993  1994  Lillehammer
# 1         Australia  AUS   23781169.0    56310.962993  1994  Lillehammer
# 2         Australia  AUS   23781169.0    56310.962993  1994  Lillehammer
# 3         Australia  AUS   23781169.0    56310.962993  1994  Lillehammer
# 4         Australia  AUS   23781169.0    56310.962993  1998       Nagano
# ...             ...  ...          ...             ...   ...          ...
# 4821  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4822  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4823  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4824  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4825     Uzbekistan  UZB   31299500.0     2132.070368  1994  Lillehammer
#
#         Sport                 Discipline              Athlete Gender  \
# 0     Skating  Short Track Speed Skating     BRADBURY, Steven    Men
# 1     Skating  Short Track Speed Skating       HANSEN, Kieran    Men
# 2     Skating  Short Track Speed Skating       MURTHA, Andrew    Men
# 3     Skating  Short Track Speed Skating   NIZIELSKI, Richard    Men
# 4      Skiing              Alpine Skiing       STEGGALL, Zali  Women
# ...       ...                        ...                  ...    ...
# 4821   Skiing                  Snowboard        DEIBOLD, Alex    Men
# 4822   Skiing                  Snowboard         CLARK, Kelly  Women
# 4823   Skiing                  Snowboard  FARRINGTON, Kaitlyn  Women
# 4824   Skiing                  Snowboard      ANDERSON, Jamie  Women
# 4825   Skiing           Freestyle Skiing     CHERYAZOVA, Lina  Women
#
#                 Event   Medal  Season
# 0         5000M Relay  Bronze  Winter
# 1         5000M Relay  Bronze  Winter
# 2         5000M Relay  Bronze  Winter
# 3         5000M Relay  Bronze  Winter
# 4              Slalom  Bronze  Winter
# ...               ...     ...     ...
# 4821  Snowboard Cross  Bronze  Winter
# 4822        Half-Pipe  Bronze  Winter
# 4823        Half-Pipe    Gold  Winter
# 4824       Slopestyle    Gold  Winter
# 4825          Aerials    Gold  Winter
#
# [4826 rows x 13 columns]

# %%
all_df = pd.concat([summer_countries_df , winter_countries_df ], axis="index", sort=False)

all_df
# Out:
#             Country Code   Population  GDP per Capita  Year         City  \
# 0       Afghanistan  AFG   32526562.0      594.323081  2008      Beijing
# 1       Afghanistan  AFG   32526562.0      594.323081  2012       London
# 2           Algeria  ALG   39666519.0     4206.031232  1984  Los Angeles
# 3           Algeria  ALG   39666519.0     4206.031232  1984  Los Angeles
# 4           Algeria  ALG   39666519.0     4206.031232  1992    Barcelona
# ...             ...  ...          ...             ...   ...          ...
# 4821  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4822  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4823  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4824  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4825     Uzbekistan  UZB   31299500.0     2132.070368  1994  Lillehammer
#
#           Sport        Discipline              Athlete Gender  \
# 0     Taekwondo         Taekwondo     NIKPAI, Rohullah    Men
# 1     Taekwondo         Taekwondo     NIKPAI, Rohullah    Men
# 2        Boxing            Boxing       ZAOUI, Mohamed    Men
# 3        Boxing            Boxing     MOUSSA, Mustapha    Men
# 4     Athletics         Athletics   BOULMERKA, Hassiba  Women
# ...         ...               ...                  ...    ...
# 4821     Skiing         Snowboard        DEIBOLD, Alex    Men
# 4822     Skiing         Snowboard         CLARK, Kelly  Women
# 4823     Skiing         Snowboard  FARRINGTON, Kaitlyn  Women
# 4824     Skiing         Snowboard      ANDERSON, Jamie  Women
# 4825     Skiing  Freestyle Skiing     CHERYAZOVA, Lina  Women
#
#                               Event   Medal  Season
# 0                           - 58 KG  Bronze  Summer
# 1                        58 - 68 KG  Bronze  Summer
# 2                           71-75KG  Bronze  Summer
# 3     75 - 81KG (Light-Heavyweight)  Bronze  Summer
# 4                             1500M    Gold  Summer
# ...                             ...     ...     ...
# 4821                Snowboard Cross  Bronze  Winter
# 4822                      Half-Pipe  Bronze  Winter
# 4823                      Half-Pipe    Gold  Winter
# 4824                     Slopestyle    Gold  Winter
# 4825                        Aerials    Gold  Winter
#
# [30568 rows x 13 columns]

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult
result = ChallengeResult('all_df',
    all_df_shape=all_df.shape,
    all_df_columns=set(all_df.columns)
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-7.1.3, pluggy-1.0.0 -- /home/victor/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/victor/code/Fenrir1958/dotfiles/3-Data Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_all_df.py::TestAllDf::test_all_df_columns PASSED                    [ 50%]
# test_all_df.py::TestAllDf::test_all_df_shape PASSED                      [100%]
#
# ============================== 2 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/all_df.pickle
#
# git commit -m 'Completed all_df step'
#
# git push origin master

# %% [markdown]
# ### Top Countries Analysis

# %%
top_10_df = all_df[all_df['Year']>=1984]

top_10_df = top_10_df.groupby(top_10_df['Country'])

top_10_df = pd.DataFrame(top_10_df['Medal'].count())

top_10_df.rename({'Medal': 'Medal Count'}, axis=1, inplace=True)

top_10_df = top_10_df.sort_values(by=['Medal Count'],ascending=False)

top_10_df = top_10_df[:10]

top_10_df
# Out:
#                Medal Count
# Country
# United States         2472
# Germany               1112
# Russia                1031
# Australia              891
# China                  889
# Canada                 801
# Italy                  632
# Korea, South           587
# France                 587
# Netherlands            563

# %%
top_10_df.plot(kind="bar");

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult
result = ChallengeResult('olympic_games',
    top_country_1=top_10_df.iloc[0]['Medal Count'],
    top_country_10=top_10_df.iloc[9]['Medal Count']
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-7.1.3, pluggy-1.0.0 -- /home/victor/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/victor/code/Fenrir1958/dotfiles/3-Data Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 1 item
#
# test_olympic_games.py::TestOlympicGames::test_top_10_countries_medals PASSED [100%]
#
# ============================== 1 passed in 0.08s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games.pickle
#
# git commit -m 'Completed olympic_games step'
#
# git push origin master

# %%
top_10_season_df = all_df[all_df['Year']>=1984]

top_10_season_df = top_10_season_df.groupby([top_10_season_df['Country'],top_10_season_df['Season']])

top_10_season_df = pd.DataFrame(top_10_season_df['Medal'].count())

top_10_season_df = top_10_season_df['Medal'].unstack(level=-1)

top_10_season_df = top_10_season_df.sort_values(by=['Summer','Winter'],ascending=False)

top_10_season_df = top_10_season_df[:10]

top_10_season_df['Total'] = top_10_season_df.sum(axis=1)

top_10_season_df
# Out:
# Season          Summer  Winter   Total
# Country
# United States   2087.0   385.0  2472.0
# Australia        876.0    15.0   891.0
# China            807.0    82.0   889.0
# Germany          785.0   327.0  1112.0
# Russia           768.0   263.0  1031.0
# United Kingdom   516.0    29.0   545.0
# Korea, South     500.0    87.0   587.0
# Italy            486.0   146.0   632.0
# France           482.0   105.0   587.0
# Netherlands      476.0    87.0   563.0

# %%
top_10_season_df[['Summer', 'Winter']].plot(kind="bar");

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult
result = ChallengeResult('olympic_games_season',
    top_country_season_shape=top_10_season_df.shape,
    top_country_1_summer=top_10_season_df.iloc[0]['Summer'],
    top_country_10_winter=top_10_season_df.iloc[9]['Winter']
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-7.1.3, pluggy-1.0.0 -- /home/victor/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/victor/code/Fenrir1958/dotfiles/3-Data Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 3 items
#
# test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_shape PASSED [ 33%]
# test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_summer PASSED [ 66%]
# test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_winter PASSED [100%]
#
# ============================== 3 passed in 0.10s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games_season.pickle
#
# git commit -m 'Completed olympic_games_season step'
#
# git push origin master

# %%
all_df[(all_df.Year==2008) & (all_df.Event=='Basketball') & (all_df.Medal=='Gold')]
# Out:
#              Country Code   Population  GDP per Capita  Year     City  \
# 25188  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25189  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25190  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25191  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25192  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25193  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25194  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25195  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25196  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25197  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25198  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25199  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25200  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25201  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25202  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25203  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25204  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25205  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25206  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25207  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25208  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25209  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25210  United States  USA  321418820.0    56115.718426  2008  Beijing
# 25211  United States  USA  321418820.0    56115.718426  2008  Beijing
#
#             Sport  Discipline                Athlete Gender       Event Medal  \
# 25188  Basketball  Basketball       ANTHONY, Carmelo    Men  Basketball  Gold
# 25189  Basketball  Basketball         BOOZER, Carlos    Men  Basketball  Gold
# 25190  Basketball  Basketball            BOSH, Chris    Men  Basketball  Gold
# 25191  Basketball  Basketball           BRYANT, Kobe    Men  Basketball  Gold
# 25192  Basketball  Basketball         HOWARD, Dwight    Men  Basketball  Gold
# 25193  Basketball  Basketball          JAMES, Lebron    Men  Basketball  Gold
# 25194  Basketball  Basketball            KIDD, Jason    Men  Basketball  Gold
# 25195  Basketball  Basketball            PAUL, Chris    Men  Basketball  Gold
# 25196  Basketball  Basketball       PRINCE, Tayshaun    Men  Basketball  Gold
# 25197  Basketball  Basketball          REDD, Michael    Men  Basketball  Gold
# 25198  Basketball  Basketball           WADE, Dwyane    Men  Basketball  Gold
# 25199  Basketball  Basketball        WILLIAMS, Deron    Men  Basketball  Gold
# 25200  Basketball  Basketball      AUGUSTUS, Seimone  Women  Basketball  Gold
# 25201  Basketball  Basketball              BIRD, Sue  Women  Basketball  Gold
# 25202  Basketball  Basketball      CATCHINGS, Tamika  Women  Basketball  Gold
# 25203  Basketball  Basketball         FOWLES, Sylvia  Women  Basketball  Gold
# 25204  Basketball  Basketball           LAWSON, Kara  Women  Basketball  Gold
# 25205  Basketball  Basketball           LESLIE, Lisa  Women  Basketball  Gold
# 25206  Basketball  Basketball  MILTON-JONES, Delisha  Women  Basketball  Gold
# 25207  Basketball  Basketball        PARKER, Candace  Women  Basketball  Gold
# 25208  Basketball  Basketball      PONDEXTER, Cappie  Women  Basketball  Gold
# 25209  Basketball  Basketball           SMITH, Katie  Women  Basketball  Gold
# 25210  Basketball  Basketball         TAURASI, Diana  Women  Basketball  Gold
# 25211  Basketball  Basketball         THOMPSON, Tina  Women  Basketball  Gold
#
#        Season
# 25188  Summer
# 25189  Summer
# 25190  Summer
# 25191  Summer
# 25192  Summer
# 25193  Summer
# 25194  Summer
# 25195  Summer
# 25196  Summer
# 25197  Summer
# 25198  Summer
# 25199  Summer
# 25200  Summer
# 25201  Summer
# 25202  Summer
# 25203  Summer
# 25204  Summer
# 25205  Summer
# 25206  Summer
# 25207  Summer
# 25208  Summer
# 25209  Summer
# 25210  Summer
# 25211  Summer

# %%
top_10_events_df = all_df

top_10_events_df
# Out:
#             Country Code   Population  GDP per Capita  Year         City  \
# 0       Afghanistan  AFG   32526562.0      594.323081  2008      Beijing
# 1       Afghanistan  AFG   32526562.0      594.323081  2012       London
# 2           Algeria  ALG   39666519.0     4206.031232  1984  Los Angeles
# 3           Algeria  ALG   39666519.0     4206.031232  1984  Los Angeles
# 4           Algeria  ALG   39666519.0     4206.031232  1992    Barcelona
# ...             ...  ...          ...             ...   ...          ...
# 4821  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4822  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4823  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4824  United States  USA  321418820.0    56115.718426  2014        Sochi
# 4825     Uzbekistan  UZB   31299500.0     2132.070368  1994  Lillehammer
#
#           Sport        Discipline              Athlete Gender  \
# 0     Taekwondo         Taekwondo     NIKPAI, Rohullah    Men
# 1     Taekwondo         Taekwondo     NIKPAI, Rohullah    Men
# 2        Boxing            Boxing       ZAOUI, Mohamed    Men
# 3        Boxing            Boxing     MOUSSA, Mustapha    Men
# 4     Athletics         Athletics   BOULMERKA, Hassiba  Women
# ...         ...               ...                  ...    ...
# 4821     Skiing         Snowboard        DEIBOLD, Alex    Men
# 4822     Skiing         Snowboard         CLARK, Kelly  Women
# 4823     Skiing         Snowboard  FARRINGTON, Kaitlyn  Women
# 4824     Skiing         Snowboard      ANDERSON, Jamie  Women
# 4825     Skiing  Freestyle Skiing     CHERYAZOVA, Lina  Women
#
#                               Event   Medal  Season
# 0                           - 58 KG  Bronze  Summer
# 1                        58 - 68 KG  Bronze  Summer
# 2                           71-75KG  Bronze  Summer
# 3     75 - 81KG (Light-Heavyweight)  Bronze  Summer
# 4                             1500M    Gold  Summer
# ...                             ...     ...     ...
# 4821                Snowboard Cross  Bronze  Winter
# 4822                      Half-Pipe  Bronze  Winter
# 4823                      Half-Pipe    Gold  Winter
# 4824                     Slopestyle    Gold  Winter
# 4825                        Aerials    Gold  Winter
#
# [30568 rows x 13 columns]

# %%
top_10_events_df.plot(kind='bar');
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 top_10_events_df.plot(kind='bar')
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/plotting/_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:336, in MPLPlot.generate(self)
#     334 for ax in self.axes:
#     335     self._post_plot_logic_common(ax, self.data)
# --> 336     self._post_plot_logic(ax, self.data)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1580, in BarPlot._post_plot_logic(self, ax, data)
#    1577 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1578 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
# -> 1580 self._decorate_ticks(ax, name, str_index, s_edge, e_edge)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1588, in BarPlot._decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge)
#    1586     ax.set_xticks(np.array(self.xticks))
#    1587 else:
# -> 1588     ax.set_xticks(self.tick_pos)
#    1589     ax.set_xticklabels(ticklabels)
#    1591 if name is not None and self.use_index:
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axes/_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      74 def wrapper(self, *args, **kwargs):
# ---> 75     return get_method(self)(*args, **kwargs)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:1855, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    1829 def set_ticks(self, ticks, labels=None, *, minor=False, **kwargs):
#    1830     """
#    1831     Set this Axis' tick locations and optionally labels.
#    1832
#    (...)
#    1853     ticks.
#    1854     """
# -> 1855     result = self._set_tick_locations(ticks, minor=minor)
#    1856     if labels is not None:
#    1857         self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:1827, in Axis._set_tick_locations(self, ticks, minor)
#    1825 else:
#    1826     self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1827     return self.get_major_ticks(len(ticks))
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:1375, in Axis.get_major_ticks(self, numticks)
#    1371     numticks = len(self.get_majorticklocs())
#    1373 while len(self.majorTicks) < numticks:
#    1374     # Update the new tick label properties from the old.
# -> 1375     tick = self._get_tick(major=True)
#    1376     self.majorTicks.append(tick)
#    1377     self._copy_tick_props(self.majorTicks[0], tick)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:2057, in XAxis._get_tick(self, major)
#    2055 else:
#    2056     tick_kw = self._minor_tick_kw
# -> 2057 return XTick(self.axes, 0, major=major, **tick_kw)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:415, in XTick.__init__(self, *args, **kwargs)
#     414 def __init__(self, *args, **kwargs):
# --> 415     super().__init__(*args, **kwargs)
#     416     # x in data coords, y in axes coords
#     417     ax = self.axes
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:150, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     147     grid_alpha = mpl.rcParams["grid.alpha"]
#     148 grid_kw = {k[5:]: v for k, v in kw.items()}
# --> 150 self.tick1line = mlines.Line2D(
#     151     [], [],
#     152     color=color, linestyle="none", zorder=zorder, visible=tick1On,
#     153     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     154 )
#     155 self.tick2line = mlines.Line2D(
#     156     [], [],
#     157     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     158     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     159 )
#     160 self.gridline = mlines.Line2D(
#     161     [], [],
#     162     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     163     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     164     **grid_kw,
#     165 )
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/lines.py:387, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     384 self._markerfacecoloralt = None
#     386 self.set_markerfacecolor(markerfacecolor)  # Normalizes None to rc.
# --> 387 self.set_markerfacecoloralt(markerfacecoloralt)
#     388 self.set_markeredgecolor(markeredgecolor)  # Normalizes None to rc.
#     389 self.set_markeredgewidth(markeredgewidth)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/lines.py:1191, in Line2D.set_markerfacecoloralt(self, fc)
#    1183 def set_markerfacecoloralt(self, fc):
#    1184     """
#    1185     Set the alternate marker face color.
#    1186
#    (...)
#    1189     fc : color
#    1190     """
# -> 1191     self._set_markercolor("markerfacecoloralt", False, fc)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/lines.py:1161, in Line2D._set_markercolor(self, name, has_rcdefault, val)
#    1159     if neq.any() if isinstance(neq, np.ndarray) else neq:
#    1160         self.stale = True
# -> 1161 setattr(self, attr, val)
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f490f2763a0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/pyplot.py:137, in install_repl_displayhook.<locals>.post_execute()
#     135 def post_execute():
#     136     if matplotlib.is_interactive():
# --> 137         draw_all()
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/_pylab_helpers.py:141, in Gcf.draw_all(cls, force)
#     139 for manager in cls.get_all_fig_managers():
#     140     if force or manager.canvas.figure.stale:
# --> 141         manager.canvas.draw_idle()
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/backend_bases.py:2060, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2058 if not self._is_idle_drawing:
#    2059     with self._idle_draw_cntx():
# -> 2060         self.draw(*args, **kwargs)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/figure.py:2845, in Figure.draw(self, renderer)
#    2842         # ValueError can occur when resizing a window.
#    2844 self.patch.draw(renderer)
# -> 2845 mimage._draw_list_compositing_images(
#    2846     renderer, self, artists, self.suppressComposite)
#    2848 for sfig in self.subfigs:
#    2849     sfig.draw(renderer)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:1158, in Axis.draw(self, renderer, *args, **kwargs)
#    1155     return
#    1156 renderer.open_group(__name__, gid=self.get_gid())
# -> 1158 ticks_to_draw = self._update_ticks()
#    1159 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                         renderer)
#    1162 for tick in ticks_to_draw:
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:1047, in Axis._update_ticks(self)
#    1045 major_locs = self.get_majorticklocs()
#    1046 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1047 major_ticks = self.get_major_ticks(len(major_locs))
#    1048 self.major.formatter.set_locs(major_locs)
#    1049 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:1375, in Axis.get_major_ticks(self, numticks)
#    1371     numticks = len(self.get_majorticklocs())
#    1373 while len(self.majorTicks) < numticks:
#    1374     # Update the new tick label properties from the old.
# -> 1375     tick = self._get_tick(major=True)
#    1376     self.majorTicks.append(tick)
#    1377     self._copy_tick_props(self.majorTicks[0], tick)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:2057, in XAxis._get_tick(self, major)
#    2055 else:
#    2056     tick_kw = self._minor_tick_kw
# -> 2057 return XTick(self.axes, 0, major=major, **tick_kw)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axis.py:426, in XTick.__init__(self, *args, **kwargs)
#     424 # the y loc is 3 points below the min of y axis
#     425 trans, va, ha = self._get_text1_transform()
# --> 426 self.label1.set(
#     427     x=0, y=0,
#     428     verticalalignment=va, horizontalalignment=ha, transform=trans,
#     429 )
#     430 trans, va, ha = self._get_text2_transform()
#     431 self.label2.set(
#     432     x=0, y=1,
#     433     verticalalignment=va, horizontalalignment=ha, transform=trans,
#     434 )
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/artist.py:117, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     109 if not hasattr(cls.set, '_autogenerated_signature'):
#     110     # Don't overwrite cls.set if the subclass or one of its parents
#     111     # has defined a set method set itself.
#     112     # If there was no explicit definition, cls.set is inherited from
#     113     # the hierarchy of auto-generated set methods, which hold the
#     114     # flag _autogenerated_signature.
#     115     return
# --> 117 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     118 cls.set.__name__ = "set"
#     119 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/artist.py:1167, in Artist.set(self, **kwargs)
#    1162 def set(self, **kwargs):
#    1163     # docstring and signature are auto-generated via
#    1164     # Artist._update_set_signature_and_docstring() at the end of the
#    1165     # module.
#    1166     kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1167     return self.update(kwargs)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/text.py:172, in Text.update(self, kwargs)
#     170 # Update bbox last, as it depends on font properties.
#     171 bbox = kwargs.pop("bbox", sentinel)
# --> 172 super().update(kwargs)
#     173 if bbox is not sentinel:
#     174     self.set_bbox(bbox)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/artist.py:1069, in Artist.update(self, props)
#    1066             if not callable(func):
#    1067                 raise AttributeError(f"{type(self).__name__!r} object "
#    1068                                      f"has no property {k!r}")
# -> 1069             ret.append(func(v))
#    1070 if ret:
#    1071     self.pchanged()
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/text.py:1203, in Text.set_verticalalignment(self, align)
#    1195 def set_verticalalignment(self, align):
#    1196     """
#    1197     Set the vertical alignment.
#    1198
#    (...)
#    1201     align : {'center', 'top', 'bottom', 'baseline', 'center_baseline'}
#    1202     """
# -> 1203     _api.check_in_list(
#    1204         ['top', 'bottom', 'center', 'baseline', 'center_baseline'],
#    1205         align=align)
#    1206     self._verticalalignment = align
#    1207     self.stale = True
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f490f2761f0> (for post_execute):
# KeyboardInterrupt

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult
result = ChallengeResult('olympic_games_event',
    top_country_event_shape=top_10_events_df.shape,
    top_country_1_event=top_10_events_df.iloc[0]['Event Count'],
    top_country_10_event=top_10_events_df.iloc[9]['Event Count']
)
result.write()
print(result.check())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Event Count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [37], line 4
#       1 from nbresult import ChallengeResult
#       2 result = ChallengeResult('olympic_games_event',
#       3     top_country_event_shape=top_10_events_df.shape,
# ----> 4     top_country_1_event=top_10_events_df.iloc[0]['Event Count'],
#       5     top_country_10_event=top_10_events_df.iloc[9]['Event Count']
#       6 )
#       7 result.write()
#       8 print(result.check())
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Event Count'
