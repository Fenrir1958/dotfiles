# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %%
import requests

url = "https://iex.lewagon.com/stable/stock/aapl/chart/3m"
api_data = requests.get(url).json()

apple_stock_df = pd.DataFrame(api_data)
apple_stock_df
# Out:
#      close      high      low    open   priceDate symbol     volume  \
# 0   193.18  193.4900  191.420  193.11  2023-12-11   AAPL   60943699
# 1   194.71  194.7200  191.721  193.08  2023-12-12   AAPL   52696900
# 2   197.96  198.0000  194.850  195.09  2023-12-13   AAPL   70404183
# 3   198.11  199.6200  196.160  198.02  2023-12-14   AAPL   66831572
# 4   197.57  198.3999  197.000  197.53  2023-12-15   AAPL  128538401
# ..     ...       ...      ...     ...         ...    ...        ...
# 56  175.10  176.9000  173.790  176.15  2024-03-04   AAPL   81510101
# 57  170.12  172.0400  169.620  170.76  2024-03-05   AAPL   95132355
# 58  169.12  171.2400  168.680  171.06  2024-03-06   AAPL   68587707
# 59  169.00  170.7300  168.490  169.15  2024-03-07   AAPL   71765061
# 60  170.73  173.7000  168.940  169.00  2024-03-08   AAPL   76267041
#
#                    id   key subkey  ...     uLow    uVolume   fOpen  fClose  \
# 0   HISTORICAL_PRICES  AAPL         ...  191.420   60943699  193.11  193.18
# 1   HISTORICAL_PRICES  AAPL         ...  191.721   52696900  193.08  194.71
# 2   HISTORICAL_PRICES  AAPL         ...  194.850   70404183  195.09  197.96
# 3   HISTORICAL_PRICES  AAPL         ...  196.160   66831572  198.02  198.11
# 4   HISTORICAL_PRICES  AAPL         ...  197.000  128538401  197.53  197.57
# ..                ...   ...    ...  ...      ...        ...     ...     ...
# 56  HISTORICAL_PRICES  AAPL         ...  173.790   81510101  176.15  175.10
# 57  HISTORICAL_PRICES  AAPL         ...  169.620   95132355  170.76  170.12
# 58  HISTORICAL_PRICES  AAPL         ...  168.680   68587707  171.06  169.12
# 59  HISTORICAL_PRICES  AAPL         ...  168.490   71765061  169.15  169.00
# 60  HISTORICAL_PRICES  AAPL         ...  168.940   76267041  169.00  170.73
#
#        fHigh     fLow    fVolume       label  change  changePercent
# 0   193.4900  191.420   60943699  Dec 11, 23    0.00         0.0000
# 1   194.7200  191.721   52696900  Dec 12, 23    1.53         0.0079
# 2   198.0000  194.850   70404183  Dec 13, 23    3.25         0.0167
# 3   199.6200  196.160   66831572  Dec 14, 23    0.15         0.0008
# 4   198.3999  197.000  128538401  Dec 15, 23   -0.54        -0.0027
# ..       ...      ...        ...         ...     ...            ...
# 56  176.9000  173.790   81510101   Mar 4, 24   -4.56        -0.0254
# 57  172.0400  169.620   95132355   Mar 5, 24   -4.98        -0.0284
# 58  171.2400  168.680   68587707   Mar 6, 24   -1.00        -0.0059
# 59  170.7300  168.490   71765061   Mar 7, 24   -0.12        -0.0007
# 60  173.7000  168.940   76267041   Mar 8, 24    1.73         0.0102
#
# [61 rows x 27 columns]

# %%
#Convert the date column to a datetime object
apple_stock_df.date = pd.to_datetime(apple_stock_df.date, format="%Y-%m-%d")

# %%
apple_stock_df.head()
# Out:
#     close      high      low    open   priceDate symbol     volume  \
# 0  193.18  193.4900  191.420  193.11  2023-12-11   AAPL   60943699
# 1  194.71  194.7200  191.721  193.08  2023-12-12   AAPL   52696900
# 2  197.96  198.0000  194.850  195.09  2023-12-13   AAPL   70404183
# 3  198.11  199.6200  196.160  198.02  2023-12-14   AAPL   66831572
# 4  197.57  198.3999  197.000  197.53  2023-12-15   AAPL  128538401
#
#                   id   key subkey  ...     uLow    uVolume   fOpen  fClose  \
# 0  HISTORICAL_PRICES  AAPL         ...  191.420   60943699  193.11  193.18
# 1  HISTORICAL_PRICES  AAPL         ...  191.721   52696900  193.08  194.71
# 2  HISTORICAL_PRICES  AAPL         ...  194.850   70404183  195.09  197.96
# 3  HISTORICAL_PRICES  AAPL         ...  196.160   66831572  198.02  198.11
# 4  HISTORICAL_PRICES  AAPL         ...  197.000  128538401  197.53  197.57
#
#       fHigh     fLow    fVolume       label  change  changePercent
# 0  193.4900  191.420   60943699  Dec 11, 23    0.00         0.0000
# 1  194.7200  191.721   52696900  Dec 12, 23    1.53         0.0079
# 2  198.0000  194.850   70404183  Dec 13, 23    3.25         0.0167
# 3  199.6200  196.160   66831572  Dec 14, 23    0.15         0.0008
# 4  198.3999  197.000  128538401  Dec 15, 23   -0.54        -0.0027
#
# [5 rows x 27 columns]

# %%
apple_stock_df.date.describe
# Out:
# <bound method NDFrame.describe of 0    2023-12-11
# 1    2023-12-12
# 2    2023-12-13
# 3    2023-12-14
# 4    2023-12-15
#         ...
# 56   2024-03-04
# 57   2024-03-05
# 58   2024-03-06
# 59   2024-03-07
# 60   2024-03-08
# Name: date, Length: 61, dtype: datetime64[ns]>

# %%
#Set the date column as the index

apple_stock_df.set_index('date', inplace=True)

# idem apple_stock_df = apple_stock_df.set_index('date')

apple_stock_df.head()
# Out:
#              close      high      low    open   priceDate symbol     volume  \
# date
# 2023-12-11  193.18  193.4900  191.420  193.11  2023-12-11   AAPL   60943699
# 2023-12-12  194.71  194.7200  191.721  193.08  2023-12-12   AAPL   52696900
# 2023-12-13  197.96  198.0000  194.850  195.09  2023-12-13   AAPL   70404183
# 2023-12-14  198.11  199.6200  196.160  198.02  2023-12-14   AAPL   66831572
# 2023-12-15  197.57  198.3999  197.000  197.53  2023-12-15   AAPL  128538401
#
#                            id   key subkey  ...     uLow    uVolume   fOpen  \
# date                                        ...
# 2023-12-11  HISTORICAL_PRICES  AAPL         ...  191.420   60943699  193.11
# 2023-12-12  HISTORICAL_PRICES  AAPL         ...  191.721   52696900  193.08
# 2023-12-13  HISTORICAL_PRICES  AAPL         ...  194.850   70404183  195.09
# 2023-12-14  HISTORICAL_PRICES  AAPL         ...  196.160   66831572  198.02
# 2023-12-15  HISTORICAL_PRICES  AAPL         ...  197.000  128538401  197.53
#
#             fClose     fHigh     fLow    fVolume       label  change  \
# date
# 2023-12-11  193.18  193.4900  191.420   60943699  Dec 11, 23    0.00
# 2023-12-12  194.71  194.7200  191.721   52696900  Dec 12, 23    1.53
# 2023-12-13  197.96  198.0000  194.850   70404183  Dec 13, 23    3.25
# 2023-12-14  198.11  199.6200  196.160   66831572  Dec 14, 23    0.15
# 2023-12-15  197.57  198.3999  197.000  128538401  Dec 15, 23   -0.54
#
#             changePercent
# date
# 2023-12-11         0.0000
# 2023-12-12         0.0079
# 2023-12-13         0.0167
# 2023-12-14         0.0008
# 2023-12-15        -0.0027
#
# [5 rows x 26 columns]

# %%
apple_stock_df.close.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#figsize in inches (width, height)!

apple_stock_df[['open', 'close', 'high', 'low']].plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from nbresult import ChallengeResult

result = ChallengeResult('apple',
    index_name=apple_stock_df.index.name,
    index_type=apple_stock_df.index.dtype,
    columns=apple_stock_df.columns
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-7.1.3, pluggy-1.0.0 -- /home/victor/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/victor/code/Fenrir1958/dotfiles/4-Data Sourcing/01-Stock-Market-API/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 3 items
#
# test_apple.py::TestApple::test_apple_df_columns PASSED                   [ 33%]
# test_apple.py::TestApple::test_apple_df_index_is_timestamp PASSED        [ 66%]
# test_apple.py::TestApple::test_apple_df_index_name_is_date PASSED        [100%]
#
# ============================== 3 passed in 0.24s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/apple.pickle
#
# git commit -m 'Completed apple step'
#
# git push origin master

# %% [markdown]
# **What is the URL for the:**
#
# Amazon stock prices since last year?
# Facebook market cap?
# Apple research and development spendings quarterly?
# Last news about Tesla?
# Performance of the ‘Energy’ sector?

# %%
url2 = "http://iex.lewagon.com/stable/stock/amzn/chart/1y"
api_data = requests.get(url2).json()

amzn_stock_df = pd.DataFrame(api_data)
amzn_stock_df.date = pd.to_datetime(amzn_stock_df.date, format="%Y-%m-%d")
amzn_stock_df.set_index('date', inplace=True)
amzn_stock_df.close.plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
api_data
# Out:
# [{'close': 92.43,
#   'high': 94.02,
#   'low': 88.12,
#   'open': 89.97,
#   'priceDate': '2023-03-13',
#   'symbol': 'AMZN',
#   'volume': 72397053,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-13',
#   'updated': 1678755674000,
#   'changeOverTime': 0,
#   'marketChangeOverTime': 0,
#   'uOpen': 89.97,
#   'uClose': 92.43,
#   'uHigh': 94.02,
#   'uLow': 88.12,
#   'uVolume': 72397053,
#   'fOpen': 89.97,
#   'fClose': 92.43,
#   'fHigh': 94.02,
#   'fLow': 88.12,
#   'fVolume': 72397053,
#   'label': 'Mar 13, 23',
#   'change': 0,
#   'changePercent': 0},
#  {'close': 94.88,
#   'high': 95.07,
#   'low': 92.71,
#   'open': 93.83,
#   'priceDate': '2023-03-14',
#   'symbol': 'AMZN',
#   'volume': 60912674,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-14',
#   'updated': 1678853050000,
#   'changeOverTime': 0.026506545493887142,
#   'marketChangeOverTime': 0.026506545493887142,
#   'uOpen': 93.83,
#   'uClose': 94.88,
#   'uHigh': 95.07,
#   'uLow': 92.71,
#   'uVolume': 60912674,
#   'fOpen': 93.83,
#   'fClose': 94.88,
#   'fHigh': 95.07,
#   'fLow': 92.71,
#   'fVolume': 60912674,
#   'label': 'Mar 14, 23',
#   'change': 2.4499999999999886,
#   'changePercent': 0.0265},
#  {'close': 96.2,
#   'high': 96.67,
#   'low': 93.07,
#   'open': 93.22,
#   'priceDate': '2023-03-15',
#   'symbol': 'AMZN',
#   'volume': 70731792,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-15',
#   'updated': 1678928496000,
#   'changeOverTime': 0.040787623066104034,
#   'marketChangeOverTime': 0.040787623066104034,
#   'uOpen': 93.22,
#   'uClose': 96.2,
#   'uHigh': 96.67,
#   'uLow': 93.07,
#   'uVolume': 70731792,
#   'fOpen': 93.22,
#   'fClose': 96.2,
#   'fHigh': 96.67,
#   'fLow': 93.07,
#   'fVolume': 70731792,
#   'label': 'Mar 15, 23',
#   'change': 1.3200000000000074,
#   'changePercent': 0.0139},
#  {'close': 100.04,
#   'high': 100.99,
#   'low': 95.61,
#   'open': 95.75,
#   'priceDate': '2023-03-16',
#   'symbol': 'AMZN',
#   'volume': 84558934,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-16',
#   'updated': 1679018458000,
#   'changeOverTime': 0.08233257600346207,
#   'marketChangeOverTime': 0.08233257600346207,
#   'uOpen': 95.75,
#   'uClose': 100.04,
#   'uHigh': 100.99,
#   'uLow': 95.61,
#   'uVolume': 84558934,
#   'fOpen': 95.75,
#   'fClose': 100.04,
#   'fHigh': 100.99,
#   'fLow': 95.61,
#   'fVolume': 84558934,
#   'label': 'Mar 16, 23',
#   'change': 3.8400000000000034,
#   'changePercent': 0.0399},
#  {'close': 98.95,
#   'high': 100.66,
#   'low': 97.455,
#   'open': 99.79,
#   'priceDate': '2023-03-17',
#   'symbol': 'AMZN',
#   'volume': 87300242,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-17',
#   'updated': 1679110325000,
#   'changeOverTime': 0.07053986800822239,
#   'marketChangeOverTime': 0.07053986800822239,
#   'uOpen': 99.79,
#   'uClose': 98.95,
#   'uHigh': 100.66,
#   'uLow': 97.455,
#   'uVolume': 87300242,
#   'fOpen': 99.79,
#   'fClose': 98.95,
#   'fHigh': 100.66,
#   'fLow': 97.455,
#   'fVolume': 87300242,
#   'label': 'Mar 17, 23',
#   'change': -1.0900000000000034,
#   'changePercent': -0.0109},
#  {'close': 97.71,
#   'high': 98.48,
#   'low': 95.7,
#   'open': 98.41,
#   'priceDate': '2023-03-20',
#   'symbol': 'AMZN',
#   'volume': 62388911,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-20',
#   'updated': 1679364369000,
#   'changeOverTime': 0.05712431028886711,
#   'marketChangeOverTime': 0.05712431028886711,
#   'uOpen': 98.41,
#   'uClose': 97.71,
#   'uHigh': 98.48,
#   'uLow': 95.7,
#   'uVolume': 62388911,
#   'fOpen': 98.41,
#   'fClose': 97.71,
#   'fHigh': 98.48,
#   'fLow': 95.7,
#   'fVolume': 62388911,
#   'label': 'Mar 20, 23',
#   'change': -1.240000000000009,
#   'changePercent': -0.0125},
#  {'close': 100.61,
#   'high': 100.845,
#   'low': 98,
#   'open': 98.14,
#   'priceDate': '2023-03-21',
#   'symbol': 'AMZN',
#   'volume': 58597275,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-21',
#   'updated': 1679448806000,
#   'changeOverTime': 0.08849940495510107,
#   'marketChangeOverTime': 0.08849940495510107,
#   'uOpen': 98.14,
#   'uClose': 100.61,
#   'uHigh': 100.845,
#   'uLow': 98,
#   'uVolume': 58597275,
#   'fOpen': 98.14,
#   'fClose': 100.61,
#   'fHigh': 100.845,
#   'fLow': 98,
#   'fVolume': 58597275,
#   'label': 'Mar 21, 23',
#   'change': 2.9000000000000057,
#   'changePercent': 0.0297},
#  {'close': 98.7,
#   'high': 102.1,
#   'low': 98.61,
#   'open': 100.45,
#   'priceDate': '2023-03-22',
#   'symbol': 'AMZN',
#   'volume': 57475365,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-22',
#   'updated': 1679536887000,
#   'changeOverTime': 0.06783511846802981,
#   'marketChangeOverTime': 0.06783511846802981,
#   'uOpen': 100.45,
#   'uClose': 98.7,
#   'uHigh': 102.1,
#   'uLow': 98.61,
#   'uVolume': 57475365,
#   'fOpen': 100.45,
#   'fClose': 98.7,
#   'fHigh': 102.1,
#   'fLow': 98.61,
#   'fVolume': 57475365,
#   'label': 'Mar 22, 23',
#   'change': -1.9099999999999966,
#   'changePercent': -0.019},
#  {'close': 98.71,
#   'high': 101.06,
#   'low': 97.62,
#   'open': 100.43,
#   'priceDate': '2023-03-23',
#   'symbol': 'AMZN',
#   'volume': 57559310,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-23',
#   'updated': 1679623333000,
#   'changeOverTime': 0.06794330844963742,
#   'marketChangeOverTime': 0.06794330844963742,
#   'uOpen': 100.43,
#   'uClose': 98.71,
#   'uHigh': 101.06,
#   'uLow': 97.62,
#   'uVolume': 57559310,
#   'fOpen': 100.43,
#   'fClose': 98.71,
#   'fHigh': 101.06,
#   'fLow': 97.62,
#   'fVolume': 57559310,
#   'label': 'Mar 23, 23',
#   'change': 0.009999999999990905,
#   'changePercent': 0.0001},
#  {'close': 98.13,
#   'high': 98.3,
#   'low': 96.4,
#   'open': 98.065,
#   'priceDate': '2023-03-24',
#   'symbol': 'AMZN',
#   'volume': 56144801,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-24',
#   'updated': 1679711987000,
#   'changeOverTime': 0.061668289516390654,
#   'marketChangeOverTime': 0.061668289516390654,
#   'uOpen': 98.065,
#   'uClose': 98.13,
#   'uHigh': 98.3,
#   'uLow': 96.4,
#   'uVolume': 56144801,
#   'fOpen': 98.065,
#   'fClose': 98.13,
#   'fHigh': 98.3,
#   'fLow': 96.4,
#   'fVolume': 56144801,
#   'label': 'Mar 24, 23',
#   'change': -0.5799999999999983,
#   'changePercent': -0.0059},
#  {'close': 98.04,
#   'high': 99.34,
#   'low': 97.08,
#   'open': 99.07,
#   'priceDate': '2023-03-27',
#   'symbol': 'AMZN',
#   'volume': 46721296,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-27',
#   'updated': 1679965249000,
#   'changeOverTime': 0.06069457968192144,
#   'marketChangeOverTime': 0.06069457968192144,
#   'uOpen': 99.07,
#   'uClose': 98.04,
#   'uHigh': 99.34,
#   'uLow': 97.08,
#   'uVolume': 46721296,
#   'fOpen': 99.07,
#   'fClose': 98.04,
#   'fHigh': 99.34,
#   'fLow': 97.08,
#   'fVolume': 46721296,
#   'label': 'Mar 27, 23',
#   'change': -0.0899999999999892,
#   'changePercent': -0.0009},
#  {'close': 97.24,
#   'high': 98.44,
#   'low': 96.29,
#   'open': 98.11,
#   'priceDate': '2023-03-28',
#   'symbol': 'AMZN',
#   'volume': 38720050,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-28',
#   'updated': 1680051672000,
#   'changeOverTime': 0.05203938115330507,
#   'marketChangeOverTime': 0.05203938115330507,
#   'uOpen': 98.11,
#   'uClose': 97.24,
#   'uHigh': 98.44,
#   'uLow': 96.29,
#   'uVolume': 38720050,
#   'fOpen': 98.11,
#   'fClose': 97.24,
#   'fHigh': 98.44,
#   'fLow': 96.29,
#   'fVolume': 38720050,
#   'label': 'Mar 28, 23',
#   'change': -0.8000000000000114,
#   'changePercent': -0.0082},
#  {'close': 100.25,
#   'high': 100.4218,
#   'low': 98.56,
#   'open': 98.69,
#   'priceDate': '2023-03-29',
#   'symbol': 'AMZN',
#   'volume': 49783279,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-29',
#   'updated': 1680138058000,
#   'changeOverTime': 0.08460456561722376,
#   'marketChangeOverTime': 0.08460456561722376,
#   'uOpen': 98.69,
#   'uClose': 100.25,
#   'uHigh': 100.4218,
#   'uLow': 98.56,
#   'uVolume': 49783279,
#   'fOpen': 98.69,
#   'fClose': 100.25,
#   'fHigh': 100.4218,
#   'fLow': 98.56,
#   'fVolume': 49783279,
#   'label': 'Mar 29, 23',
#   'change': 3.010000000000005,
#   'changePercent': 0.031},
#  {'close': 102,
#   'high': 103.04,
#   'low': 101.01,
#   'open': 101.55,
#   'priceDate': '2023-03-30',
#   'symbol': 'AMZN',
#   'volume': 53633398,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-30',
#   'updated': 1680246072000,
#   'changeOverTime': 0.10353781239857181,
#   'marketChangeOverTime': 0.10353781239857181,
#   'uOpen': 101.55,
#   'uClose': 102,
#   'uHigh': 103.04,
#   'uLow': 101.01,
#   'uVolume': 53633398,
#   'fOpen': 101.55,
#   'fClose': 102,
#   'fHigh': 103.04,
#   'fLow': 101.01,
#   'fVolume': 53633398,
#   'label': 'Mar 30, 23',
#   'change': 1.75,
#   'changePercent': 0.0175},
#  {'close': 103.29,
#   'high': 103.49,
#   'low': 101.95,
#   'open': 102.16,
#   'priceDate': '2023-03-31',
#   'symbol': 'AMZN',
#   'volume': 56750317,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-03-31',
#   'updated': 1680316633000,
#   'changeOverTime': 0.11749432002596558,
#   'marketChangeOverTime': 0.11749432002596558,
#   'uOpen': 102.16,
#   'uClose': 103.29,
#   'uHigh': 103.49,
#   'uLow': 101.95,
#   'uVolume': 56750317,
#   'fOpen': 102.16,
#   'fClose': 103.29,
#   'fHigh': 103.49,
#   'fLow': 101.95,
#   'fVolume': 56750317,
#   'label': 'Mar 31, 23',
#   'change': 1.2900000000000063,
#   'changePercent': 0.0126},
#  {'close': 102.41,
#   'high': 103.29,
#   'low': 101.43,
#   'open': 102.3,
#   'priceDate': '2023-04-03',
#   'symbol': 'AMZN',
#   'volume': 41135733,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-03',
#   'updated': 1680575431000,
#   'changeOverTime': 0.1079736016444876,
#   'marketChangeOverTime': 0.1079736016444876,
#   'uOpen': 102.3,
#   'uClose': 102.41,
#   'uHigh': 103.29,
#   'uLow': 101.43,
#   'uVolume': 41135733,
#   'fOpen': 102.3,
#   'fClose': 102.41,
#   'fHigh': 103.29,
#   'fLow': 101.43,
#   'fVolume': 41135733,
#   'label': 'Apr 3, 23',
#   'change': -0.8800000000000097,
#   'changePercent': -0.0085},
#  {'close': 103.95,
#   'high': 104.2,
#   'low': 102.11,
#   'open': 102.75,
#   'priceDate': '2023-04-04',
#   'symbol': 'AMZN',
#   'volume': 48662496,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-04',
#   'updated': 1680656496000,
#   'changeOverTime': 0.12463485881207395,
#   'marketChangeOverTime': 0.12463485881207395,
#   'uOpen': 102.75,
#   'uClose': 103.95,
#   'uHigh': 104.2,
#   'uLow': 102.11,
#   'uVolume': 48662496,
#   'fOpen': 102.75,
#   'fClose': 103.95,
#   'fHigh': 104.2,
#   'fLow': 102.11,
#   'fVolume': 48662496,
#   'label': 'Apr 4, 23',
#   'change': 1.5400000000000063,
#   'changePercent': 0.015},
#  {'close': 101.1,
#   'high': 103.91,
#   'low': 100.7506,
#   'open': 103.91,
#   'priceDate': '2023-04-05',
#   'symbol': 'AMZN',
#   'volume': 45175393,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-05',
#   'updated': 1680742857000,
#   'changeOverTime': 0.09380071405387846,
#   'marketChangeOverTime': 0.09380071405387846,
#   'uOpen': 103.91,
#   'uClose': 101.1,
#   'uHigh': 103.91,
#   'uLow': 100.7506,
#   'uVolume': 45175393,
#   'fOpen': 103.91,
#   'fClose': 101.1,
#   'fHigh': 103.91,
#   'fLow': 100.7506,
#   'fVolume': 45175393,
#   'label': 'Apr 5, 23',
#   'change': -2.8500000000000085,
#   'changePercent': -0.0274},
#  {'close': 102.06,
#   'high': 102.3817,
#   'low': 99.8008,
#   'open': 100.75,
#   'priceDate': '2023-04-06',
#   'symbol': 'AMZN',
#   'volume': 43808020,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-06',
#   'updated': 1680829253000,
#   'changeOverTime': 0.10418695228821806,
#   'marketChangeOverTime': 0.10418695228821806,
#   'uOpen': 100.75,
#   'uClose': 102.06,
#   'uHigh': 102.3817,
#   'uLow': 99.8008,
#   'uVolume': 43808020,
#   'fOpen': 100.75,
#   'fClose': 102.06,
#   'fHigh': 102.3817,
#   'fLow': 99.8008,
#   'fVolume': 43808020,
#   'label': 'Apr 6, 23',
#   'change': 0.960000000000008,
#   'changePercent': 0.0095},
#  {'close': 102.17,
#   'high': 102.2,
#   'low': 99.57,
#   'open': 100.96,
#   'priceDate': '2023-04-10',
#   'symbol': 'AMZN',
#   'volume': 37261185,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-10',
#   'updated': 1681174840000,
#   'changeOverTime': 0.10537704208590279,
#   'marketChangeOverTime': 0.10537704208590279,
#   'uOpen': 100.96,
#   'uClose': 102.17,
#   'uHigh': 102.2,
#   'uLow': 99.57,
#   'uVolume': 37261185,
#   'fOpen': 100.96,
#   'fClose': 102.17,
#   'fHigh': 102.2,
#   'fLow': 99.57,
#   'fVolume': 37261185,
#   'label': 'Apr 10, 23',
#   'change': 0.10999999999999943,
#   'changePercent': 0.0011},
#  {'close': 99.92,
#   'high': 101,
#   'low': 99.01,
#   'open': 100.8,
#   'priceDate': '2023-04-11',
#   'symbol': 'AMZN',
#   'volume': 60417847,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-11',
#   'updated': 1681268429000,
#   'changeOverTime': 0.08103429622416958,
#   'marketChangeOverTime': 0.08103429622416958,
#   'uOpen': 100.8,
#   'uClose': 99.92,
#   'uHigh': 101,
#   'uLow': 99.01,
#   'uVolume': 60417847,
#   'fOpen': 100.8,
#   'fClose': 99.92,
#   'fHigh': 101,
#   'fLow': 99.01,
#   'fVolume': 60417847,
#   'label': 'Apr 11, 23',
#   'change': -2.25,
#   'changePercent': -0.022},
#  {'close': 97.83,
#   'high': 100.51,
#   'low': 97.705,
#   'open': 100.4,
#   'priceDate': '2023-04-12',
#   'symbol': 'AMZN',
#   'volume': 56735007,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-12',
#   'updated': 1681347658000,
#   'changeOverTime': 0.05842259006815959,
#   'marketChangeOverTime': 0.05842259006815959,
#   'uOpen': 100.4,
#   'uClose': 97.83,
#   'uHigh': 100.51,
#   'uLow': 97.705,
#   'uVolume': 56735007,
#   'fOpen': 100.4,
#   'fClose': 97.83,
#   'fHigh': 100.51,
#   'fLow': 97.705,
#   'fVolume': 56735007,
#   'label': 'Apr 12, 23',
#   'change': -2.0900000000000034,
#   'changePercent': -0.0209},
#  {'close': 102.4,
#   'high': 102.57,
#   'low': 98.71,
#   'open': 98.95,
#   'priceDate': '2023-04-13',
#   'symbol': 'AMZN',
#   'volume': 67925138,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-13',
#   'updated': 1681437640000,
#   'changeOverTime': 0.10786541166288,
#   'marketChangeOverTime': 0.10786541166288,
#   'uOpen': 98.95,
#   'uClose': 102.4,
#   'uHigh': 102.57,
#   'uLow': 98.71,
#   'uVolume': 67925138,
#   'fOpen': 98.95,
#   'fClose': 102.4,
#   'fHigh': 102.57,
#   'fLow': 98.71,
#   'fVolume': 67925138,
#   'label': 'Apr 13, 23',
#   'change': 4.570000000000007,
#   'changePercent': 0.0467},
#  {'close': 102.51,
#   'high': 103.2013,
#   'low': 101.11,
#   'open': 102.07,
#   'priceDate': '2023-04-14',
#   'symbol': 'AMZN',
#   'volume': 51450522,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-14',
#   'updated': 1681529438000,
#   'changeOverTime': 0.10905550146056472,
#   'marketChangeOverTime': 0.10905550146056472,
#   'uOpen': 102.07,
#   'uClose': 102.51,
#   'uHigh': 103.2013,
#   'uLow': 101.11,
#   'uVolume': 51450522,
#   'fOpen': 102.07,
#   'fClose': 102.51,
#   'fHigh': 103.2013,
#   'fLow': 101.11,
#   'fVolume': 51450522,
#   'label': 'Apr 14, 23',
#   'change': 0.10999999999999943,
#   'changePercent': 0.0011},
#  {'close': 102.74,
#   'high': 103.73,
#   'low': 101.59,
#   'open': 103.16,
#   'priceDate': '2023-04-17',
#   'symbol': 'AMZN',
#   'volume': 39919457,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-17',
#   'updated': 1681783236000,
#   'changeOverTime': 0.11154387103754179,
#   'marketChangeOverTime': 0.11154387103754179,
#   'uOpen': 103.16,
#   'uClose': 102.74,
#   'uHigh': 103.73,
#   'uLow': 101.59,
#   'uVolume': 39919457,
#   'fOpen': 103.16,
#   'fClose': 102.74,
#   'fHigh': 103.73,
#   'fLow': 101.59,
#   'fVolume': 39919457,
#   'label': 'Apr 17, 23',
#   'change': 0.22999999999998977,
#   'changePercent': 0.0022},
#  {'close': 102.3,
#   'high': 104.2,
#   'low': 101.52,
#   'open': 103.95,
#   'priceDate': '2023-04-18',
#   'symbol': 'AMZN',
#   'volume': 39790518,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-18',
#   'updated': 1681866026000,
#   'changeOverTime': 0.10678351184680288,
#   'marketChangeOverTime': 0.10678351184680288,
#   'uOpen': 103.95,
#   'uClose': 102.3,
#   'uHigh': 104.2,
#   'uLow': 101.52,
#   'uVolume': 39790518,
#   'fOpen': 103.95,
#   'fClose': 102.3,
#   'fHigh': 104.2,
#   'fLow': 101.52,
#   'fVolume': 39790518,
#   'label': 'Apr 18, 23',
#   'change': -0.4399999999999977,
#   'changePercent': -0.0043},
#  {'close': 104.3,
#   'high': 105.12,
#   'low': 101.39,
#   'open': 101.58,
#   'priceDate': '2023-04-19',
#   'symbol': 'AMZN',
#   'volume': 58398890,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-19',
#   'updated': 1681956050000,
#   'changeOverTime': 0.1284215081683435,
#   'marketChangeOverTime': 0.1284215081683435,
#   'uOpen': 101.58,
#   'uClose': 104.3,
#   'uHigh': 105.12,
#   'uLow': 101.39,
#   'uVolume': 58398890,
#   'fOpen': 101.58,
#   'fClose': 104.3,
#   'fHigh': 105.12,
#   'fLow': 101.39,
#   'fVolume': 58398890,
#   'label': 'Apr 19, 23',
#   'change': 2,
#   'changePercent': 0.0196},
#  {'close': 103.81,
#   'high': 105.25,
#   'low': 103.21,
#   'open': 103.53,
#   'priceDate': '2023-04-20',
#   'symbol': 'AMZN',
#   'volume': 57696866,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-20',
#   'updated': 1682040628000,
#   'changeOverTime': 0.1231201990695661,
#   'marketChangeOverTime': 0.1231201990695661,
#   'uOpen': 103.53,
#   'uClose': 103.81,
#   'uHigh': 105.25,
#   'uLow': 103.21,
#   'uVolume': 57696866,
#   'fOpen': 103.53,
#   'fClose': 103.81,
#   'fHigh': 105.25,
#   'fLow': 103.21,
#   'fVolume': 57696866,
#   'label': 'Apr 20, 23',
#   'change': -0.4899999999999949,
#   'changePercent': -0.0047},
#  {'close': 106.96,
#   'high': 108.15,
#   'low': 105.08,
#   'open': 106.1,
#   'priceDate': '2023-04-21',
#   'symbol': 'AMZN',
#   'volume': 86774185,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-21',
#   'updated': 1682127020000,
#   'changeOverTime': 0.1572000432759925,
#   'marketChangeOverTime': 0.1572000432759925,
#   'uOpen': 106.1,
#   'uClose': 106.96,
#   'uHigh': 108.15,
#   'uLow': 105.08,
#   'uVolume': 86774185,
#   'fOpen': 106.1,
#   'fClose': 106.96,
#   'fHigh': 108.15,
#   'fLow': 105.08,
#   'fVolume': 86774185,
#   'label': 'Apr 21, 23',
#   'change': 3.1499999999999915,
#   'changePercent': 0.0303},
#  {'close': 106.21,
#   'high': 109.23,
#   'low': 105.07,
#   'open': 107.655,
#   'priceDate': '2023-04-24',
#   'symbol': 'AMZN',
#   'volume': 69575610,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-24',
#   'updated': 1682384447000,
#   'changeOverTime': 0.14908579465541474,
#   'marketChangeOverTime': 0.14908579465541474,
#   'uOpen': 107.655,
#   'uClose': 106.21,
#   'uHigh': 109.23,
#   'uLow': 105.07,
#   'uVolume': 69575610,
#   'fOpen': 107.655,
#   'fClose': 106.21,
#   'fHigh': 109.23,
#   'fLow': 105.07,
#   'fVolume': 69575610,
#   'label': 'Apr 24, 23',
#   'change': -0.75,
#   'changePercent': -0.007},
#  {'close': 102.57,
#   'high': 105.45,
#   'low': 102.45,
#   'open': 104.91,
#   'priceDate': '2023-04-25',
#   'symbol': 'AMZN',
#   'volume': 65026818,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-25',
#   'updated': 1682470866000,
#   'changeOverTime': 0.10970464135021081,
#   'marketChangeOverTime': 0.10970464135021081,
#   'uOpen': 104.91,
#   'uClose': 102.57,
#   'uHigh': 105.45,
#   'uLow': 102.45,
#   'uVolume': 65026818,
#   'fOpen': 104.91,
#   'fClose': 102.57,
#   'fHigh': 105.45,
#   'fLow': 102.45,
#   'fVolume': 65026818,
#   'label': 'Apr 25, 23',
#   'change': -3.6400000000000006,
#   'changePercent': -0.0343},
#  {'close': 104.98,
#   'high': 106.62,
#   'low': 104.1,
#   'open': 105.04,
#   'priceDate': '2023-04-26',
#   'symbol': 'AMZN',
#   'volume': 73803790,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-26',
#   'updated': 1682566239000,
#   'changeOverTime': 0.1357784269176674,
#   'marketChangeOverTime': 0.1357784269176674,
#   'uOpen': 105.04,
#   'uClose': 104.98,
#   'uHigh': 106.62,
#   'uLow': 104.1,
#   'uVolume': 73803790,
#   'fOpen': 105.04,
#   'fClose': 104.98,
#   'fHigh': 106.62,
#   'fLow': 104.1,
#   'fVolume': 73803790,
#   'label': 'Apr 26, 23',
#   'change': 2.410000000000011,
#   'changePercent': 0.0235},
#  {'close': 109.82,
#   'high': 110.86,
#   'low': 106.8,
#   'open': 108.16,
#   'priceDate': '2023-04-27',
#   'symbol': 'AMZN',
#   'volume': 149961167,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-27',
#   'updated': 1682647239000,
#   'changeOverTime': 0.18814237801579559,
#   'marketChangeOverTime': 0.18814237801579559,
#   'uOpen': 108.16,
#   'uClose': 109.82,
#   'uHigh': 110.86,
#   'uLow': 106.8,
#   'uVolume': 149961167,
#   'fOpen': 108.16,
#   'fClose': 109.82,
#   'fHigh': 110.86,
#   'fLow': 106.8,
#   'fVolume': 149961167,
#   'label': 'Apr 27, 23',
#   'change': 4.839999999999989,
#   'changePercent': 0.0461},
#  {'close': 105.45,
#   'high': 109.48,
#   'low': 104.33,
#   'open': 107.73,
#   'priceDate': '2023-04-28',
#   'symbol': 'AMZN',
#   'volume': 130715946,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-04-28',
#   'updated': 1682731831000,
#   'changeOverTime': 0.14086335605322942,
#   'marketChangeOverTime': 0.14086335605322942,
#   'uOpen': 107.73,
#   'uClose': 105.45,
#   'uHigh': 109.48,
#   'uLow': 104.33,
#   'uVolume': 130715946,
#   'fOpen': 107.73,
#   'fClose': 105.45,
#   'fHigh': 109.48,
#   'fLow': 104.33,
#   'fVolume': 130715946,
#   'label': 'Apr 28, 23',
#   'change': -4.36999999999999,
#   'changePercent': -0.0398},
#  {'close': 102.05,
#   'high': 105.23,
#   'low': 101.82,
#   'open': 104.95,
#   'priceDate': '2023-05-01',
#   'symbol': 'AMZN',
#   'volume': 74728096,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-01',
#   'updated': 1682992863000,
#   'changeOverTime': 0.1040787623066103,
#   'marketChangeOverTime': 0.1040787623066103,
#   'uOpen': 104.95,
#   'uClose': 102.05,
#   'uHigh': 105.23,
#   'uLow': 101.82,
#   'uVolume': 74728096,
#   'fOpen': 104.95,
#   'fClose': 102.05,
#   'fHigh': 105.23,
#   'fLow': 101.82,
#   'fVolume': 74728096,
#   'label': 'May 1, 23',
#   'change': -3.4000000000000057,
#   'changePercent': -0.0322},
#  {'close': 103.63,
#   'high': 103.9,
#   'low': 101.15,
#   'open': 101.47,
#   'priceDate': '2023-05-02',
#   'symbol': 'AMZN',
#   'volume': 73469350,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-02',
#   'updated': 1683075705000,
#   'changeOverTime': 0.12117277940062737,
#   'marketChangeOverTime': 0.12117277940062737,
#   'uOpen': 101.47,
#   'uClose': 103.63,
#   'uHigh': 103.9,
#   'uLow': 101.15,
#   'uVolume': 73469350,
#   'fOpen': 101.47,
#   'fClose': 103.63,
#   'fHigh': 103.9,
#   'fLow': 101.15,
#   'fVolume': 73469350,
#   'label': 'May 2, 23',
#   'change': 1.5799999999999983,
#   'changePercent': 0.0155},
#  {'close': 103.65,
#   'high': 105.96,
#   'low': 103.28,
#   'open': 103.735,
#   'priceDate': '2023-05-03',
#   'symbol': 'AMZN',
#   'volume': 65051925,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-03',
#   'updated': 1683162061000,
#   'changeOverTime': 0.12138915936384288,
#   'marketChangeOverTime': 0.12138915936384288,
#   'uOpen': 103.735,
#   'uClose': 103.65,
#   'uHigh': 105.96,
#   'uLow': 103.28,
#   'uVolume': 65051925,
#   'fOpen': 103.735,
#   'fClose': 103.65,
#   'fHigh': 105.96,
#   'fLow': 103.28,
#   'fVolume': 65051925,
#   'label': 'May 3, 23',
#   'change': 0.020000000000010232,
#   'changePercent': 0.0002},
#  {'close': 104,
#   'high': 105.39,
#   'low': 103.3117,
#   'open': 104.04,
#   'priceDate': '2023-05-04',
#   'symbol': 'AMZN',
#   'volume': 45345523,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-04',
#   'updated': 1683248468000,
#   'changeOverTime': 0.12517580872011244,
#   'marketChangeOverTime': 0.12517580872011244,
#   'uOpen': 104.04,
#   'uClose': 104,
#   'uHigh': 105.39,
#   'uLow': 103.3117,
#   'uVolume': 45345523,
#   'fOpen': 104.04,
#   'fClose': 104,
#   'fHigh': 105.39,
#   'fLow': 103.3117,
#   'fVolume': 45345523,
#   'label': 'May 4, 23',
#   'change': 0.3499999999999943,
#   'changePercent': 0.0034},
#  {'close': 105.655,
#   'high': 105.76,
#   'low': 103.55,
#   'open': 104.27,
#   'priceDate': '2023-05-05',
#   'symbol': 'AMZN',
#   'volume': 56951744,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-05',
#   'updated': 1683336626000,
#   'changeOverTime': 0.14308125067618732,
#   'marketChangeOverTime': 0.14308125067618732,
#   'uOpen': 104.27,
#   'uClose': 105.655,
#   'uHigh': 105.76,
#   'uLow': 103.55,
#   'uVolume': 56951744,
#   'fOpen': 104.27,
#   'fClose': 105.655,
#   'fHigh': 105.76,
#   'fLow': 103.55,
#   'fVolume': 56951744,
#   'label': 'May 5, 23',
#   'change': 1.6550000000000011,
#   'changePercent': 0.0159},
#  {'close': 105.83,
#   'high': 106.095,
#   'low': 104.7001,
#   'open': 105.04,
#   'priceDate': '2023-05-08',
#   'symbol': 'AMZN',
#   'volume': 49430909,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-08',
#   'updated': 1683594027000,
#   'changeOverTime': 0.1449745753543221,
#   'marketChangeOverTime': 0.1449745753543221,
#   'uOpen': 105.04,
#   'uClose': 105.83,
#   'uHigh': 106.095,
#   'uLow': 104.7001,
#   'uVolume': 49430909,
#   'fOpen': 105.04,
#   'fClose': 105.83,
#   'fHigh': 106.095,
#   'fLow': 104.7001,
#   'fVolume': 49430909,
#   'label': 'May 8, 23',
#   'change': 0.17499999999999716,
#   'changePercent': 0.0017},
#  {'close': 106.62,
#   'high': 106.79,
#   'low': 105.1567,
#   'open': 105.48,
#   'priceDate': '2023-05-09',
#   'symbol': 'AMZN',
#   'volume': 44089359,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-09',
#   'updated': 1683680438000,
#   'changeOverTime': 0.1535215839013307,
#   'marketChangeOverTime': 0.1535215839013307,
#   'uOpen': 105.48,
#   'uClose': 106.62,
#   'uHigh': 106.79,
#   'uLow': 105.1567,
#   'uVolume': 44089359,
#   'fOpen': 105.48,
#   'fClose': 106.62,
#   'fHigh': 106.79,
#   'fLow': 105.1567,
#   'fVolume': 44089359,
#   'label': 'May 9, 23',
#   'change': 0.7900000000000063,
#   'changePercent': 0.0075},
#  {'close': 110.19,
#   'high': 110.67,
#   'low': 108.05,
#   'open': 108.1,
#   'priceDate': '2023-05-10',
#   'symbol': 'AMZN',
#   'volume': 78627616,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-10',
#   'updated': 1683766862000,
#   'changeOverTime': 0.19214540733528063,
#   'marketChangeOverTime': 0.19214540733528063,
#   'uOpen': 108.1,
#   'uClose': 110.19,
#   'uHigh': 110.67,
#   'uLow': 108.05,
#   'uVolume': 78627616,
#   'fOpen': 108.1,
#   'fClose': 110.19,
#   'fHigh': 110.67,
#   'fLow': 108.05,
#   'fVolume': 78627616,
#   'label': 'May 10, 23',
#   'change': 3.569999999999993,
#   'changePercent': 0.0335},
#  {'close': 112.18,
#   'high': 113.28,
#   'low': 110.49,
#   'open': 111.03,
#   'priceDate': '2023-05-11',
#   'symbol': 'AMZN',
#   'volume': 74924841,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-11',
#   'updated': 1683853240000,
#   'changeOverTime': 0.21367521367521367,
#   'marketChangeOverTime': 0.21367521367521367,
#   'uOpen': 111.03,
#   'uClose': 112.18,
#   'uHigh': 113.28,
#   'uLow': 110.49,
#   'uVolume': 74924841,
#   'fOpen': 111.03,
#   'fClose': 112.18,
#   'fHigh': 113.28,
#   'fLow': 110.49,
#   'fVolume': 74924841,
#   'label': 'May 11, 23',
#   'change': 1.990000000000009,
#   'changePercent': 0.0181},
#  {'close': 110.26,
#   'high': 112.64,
#   'low': 109.3185,
#   'open': 112.16,
#   'priceDate': '2023-05-12',
#   'symbol': 'AMZN',
#   'volume': 49852671,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-12',
#   'updated': 1683942107000,
#   'changeOverTime': 0.19290273720653464,
#   'marketChangeOverTime': 0.19290273720653464,
#   'uOpen': 112.16,
#   'uClose': 110.26,
#   'uHigh': 112.64,
#   'uLow': 109.3185,
#   'uVolume': 49852671,
#   'fOpen': 112.16,
#   'fClose': 110.26,
#   'fHigh': 112.64,
#   'fLow': 109.3185,
#   'fVolume': 49852671,
#   'label': 'May 12, 23',
#   'change': -1.9200000000000017,
#   'changePercent': -0.0171},
#  {'close': 111.2,
#   'high': 112.29,
#   'low': 109.25,
#   'open': 111.15,
#   'priceDate': '2023-05-15',
#   'symbol': 'AMZN',
#   'volume': 53011145,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-15',
#   'updated': 1684198860000,
#   'changeOverTime': 0.2030725954776587,
#   'marketChangeOverTime': 0.2030725954776587,
#   'uOpen': 111.15,
#   'uClose': 111.2,
#   'uHigh': 112.29,
#   'uLow': 109.25,
#   'uVolume': 53011145,
#   'fOpen': 111.15,
#   'fClose': 111.2,
#   'fHigh': 112.29,
#   'fLow': 109.25,
#   'fVolume': 53011145,
#   'label': 'May 15, 23',
#   'change': 0.9399999999999977,
#   'changePercent': 0.0085},
#  {'close': 113.4,
#   'high': 114.7899,
#   'low': 111.05,
#   'open': 111.05,
#   'priceDate': '2023-05-16',
#   'symbol': 'AMZN',
#   'volume': 71472908,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-16',
#   'updated': 1684285229000,
#   'changeOverTime': 0.22687439143135343,
#   'marketChangeOverTime': 0.22687439143135343,
#   'uOpen': 111.05,
#   'uClose': 113.4,
#   'uHigh': 114.7899,
#   'uLow': 111.05,
#   'uVolume': 71472908,
#   'fOpen': 111.05,
#   'fClose': 113.4,
#   'fHigh': 114.7899,
#   'fLow': 111.05,
#   'fVolume': 71472908,
#   'label': 'May 16, 23',
#   'change': 2.200000000000003,
#   'changePercent': 0.0198},
#  {'close': 115.5,
#   'high': 115.83,
#   'low': 114.22,
#   'open': 114.89,
#   'priceDate': '2023-05-17',
#   'symbol': 'AMZN',
#   'volume': 65655177,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-17',
#   'updated': 1684375232000,
#   'changeOverTime': 0.249594287568971,
#   'marketChangeOverTime': 0.249594287568971,
#   'uOpen': 114.89,
#   'uClose': 115.5,
#   'uHigh': 115.83,
#   'uLow': 114.22,
#   'uVolume': 65655177,
#   'fOpen': 114.89,
#   'fClose': 115.5,
#   'fHigh': 115.83,
#   'fLow': 114.22,
#   'fVolume': 65655177,
#   'label': 'May 17, 23',
#   'change': 2.0999999999999943,
#   'changePercent': 0.0185},
#  {'close': 118.15,
#   'high': 118.6,
#   'low': 116.335,
#   'open': 116.69,
#   'priceDate': '2023-05-18',
#   'symbol': 'AMZN',
#   'volume': 73174087,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-18',
#   'updated': 1684458055000,
#   'changeOverTime': 0.2782646326950124,
#   'marketChangeOverTime': 0.2782646326950124,
#   'uOpen': 116.69,
#   'uClose': 118.15,
#   'uHigh': 118.6,
#   'uLow': 116.335,
#   'uVolume': 73174087,
#   'fOpen': 116.69,
#   'fClose': 118.15,
#   'fHigh': 118.6,
#   'fLow': 116.335,
#   'fVolume': 73174087,
#   'label': 'May 18, 23',
#   'change': 2.6500000000000057,
#   'changePercent': 0.0229},
#  {'close': 116.25,
#   'high': 118.31,
#   'low': 115.7,
#   'open': 118.16,
#   'priceDate': '2023-05-19',
#   'symbol': 'AMZN',
#   'volume': 55056307,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-19',
#   'updated': 1684546225000,
#   'changeOverTime': 0.25770853618954875,
#   'marketChangeOverTime': 0.25770853618954875,
#   'uOpen': 118.16,
#   'uClose': 116.25,
#   'uHigh': 118.31,
#   'uLow': 115.7,
#   'uVolume': 55056307,
#   'fOpen': 118.16,
#   'fClose': 116.25,
#   'fHigh': 118.31,
#   'fLow': 115.7,
#   'fVolume': 55056307,
#   'label': 'May 19, 23',
#   'change': -1.9000000000000057,
#   'changePercent': -0.0161},
#  {'close': 115.01,
#   'high': 116.77,
#   'low': 114.25,
#   'open': 116.77,
#   'priceDate': '2023-05-22',
#   'symbol': 'AMZN',
#   'volume': 70741123,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-22',
#   'updated': 1684807237000,
#   'changeOverTime': 0.24429297847019363,
#   'marketChangeOverTime': 0.24429297847019363,
#   'uOpen': 116.77,
#   'uClose': 115.01,
#   'uHigh': 116.77,
#   'uLow': 114.25,
#   'uVolume': 70741123,
#   'fOpen': 116.77,
#   'fClose': 115.01,
#   'fHigh': 116.77,
#   'fLow': 114.25,
#   'fVolume': 70741123,
#   'label': 'May 22, 23',
#   'change': -1.2399999999999949,
#   'changePercent': -0.0107},
#  {'close': 114.99,
#   'high': 117.14,
#   'low': 113.78,
#   'open': 114.27,
#   'priceDate': '2023-05-23',
#   'symbol': 'AMZN',
#   'volume': 67576262,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-23',
#   'updated': 1684890032000,
#   'changeOverTime': 0.2440765985069781,
#   'marketChangeOverTime': 0.2440765985069781,
#   'uOpen': 114.27,
#   'uClose': 114.99,
#   'uHigh': 117.14,
#   'uLow': 113.78,
#   'uVolume': 67576262,
#   'fOpen': 114.27,
#   'fClose': 114.99,
#   'fHigh': 117.14,
#   'fLow': 113.78,
#   'fVolume': 67576262,
#   'label': 'May 23, 23',
#   'change': -0.020000000000010232,
#   'changePercent': -0.0002},
#  {'close': 116.75,
#   'high': 117.34,
#   'low': 115.02,
#   'open': 115.35,
#   'priceDate': '2023-05-24',
#   'symbol': 'AMZN',
#   'volume': 63487938,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-24',
#   'updated': 1684980061000,
#   'changeOverTime': 0.26311803526993394,
#   'marketChangeOverTime': 0.26311803526993394,
#   'uOpen': 115.35,
#   'uClose': 116.75,
#   'uHigh': 117.34,
#   'uLow': 115.02,
#   'uVolume': 63487938,
#   'fOpen': 115.35,
#   'fClose': 116.75,
#   'fHigh': 117.34,
#   'fLow': 115.02,
#   'fVolume': 63487938,
#   'label': 'May 24, 23',
#   'change': 1.7600000000000051,
#   'changePercent': 0.0153},
#  {'close': 115,
#   'high': 116.87,
#   'low': 114.31,
#   'open': 116.63,
#   'priceDate': '2023-05-25',
#   'symbol': 'AMZN',
#   'volume': 66496681,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-25',
#   'updated': 1685064630000,
#   'changeOverTime': 0.24418478848858585,
#   'marketChangeOverTime': 0.24418478848858585,
#   'uOpen': 116.63,
#   'uClose': 115,
#   'uHigh': 116.87,
#   'uLow': 114.31,
#   'uVolume': 66496681,
#   'fOpen': 116.63,
#   'fClose': 115,
#   'fHigh': 116.87,
#   'fLow': 114.31,
#   'fVolume': 66496681,
#   'label': 'May 25, 23',
#   'change': -1.75,
#   'changePercent': -0.015},
#  {'close': 120.11,
#   'high': 121.5,
#   'low': 116.02,
#   'open': 116.04,
#   'priceDate': '2023-05-26',
#   'symbol': 'AMZN',
#   'volume': 96779889,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-26',
#   'updated': 1685151030000,
#   'changeOverTime': 0.29946986909012213,
#   'marketChangeOverTime': 0.29946986909012213,
#   'uOpen': 116.04,
#   'uClose': 120.11,
#   'uHigh': 121.5,
#   'uLow': 116.02,
#   'uVolume': 96779889,
#   'fOpen': 116.04,
#   'fClose': 120.11,
#   'fHigh': 121.5,
#   'fLow': 116.02,
#   'fVolume': 96779889,
#   'label': 'May 26, 23',
#   'change': 5.109999999999999,
#   'changePercent': 0.0444},
#  {'close': 121.66,
#   'high': 122.92,
#   'low': 119.855,
#   'open': 122.37,
#   'priceDate': '2023-05-30',
#   'symbol': 'AMZN',
#   'volume': 64314808,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-30',
#   'updated': 1685494931000,
#   'changeOverTime': 0.3162393162393161,
#   'marketChangeOverTime': 0.3162393162393161,
#   'uOpen': 122.37,
#   'uClose': 121.66,
#   'uHigh': 122.92,
#   'uLow': 119.855,
#   'uVolume': 64314808,
#   'fOpen': 122.37,
#   'fClose': 121.66,
#   'fHigh': 122.92,
#   'fLow': 119.855,
#   'fVolume': 64314808,
#   'label': 'May 30, 23',
#   'change': 1.5499999999999972,
#   'changePercent': 0.0129},
#  {'close': 120.58,
#   'high': 122.04,
#   'low': 119.17,
#   'open': 121.45,
#   'priceDate': '2023-05-31',
#   'symbol': 'AMZN',
#   'volume': 72800787,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-05-31',
#   'updated': 1685721792000,
#   'changeOverTime': 0.3045547982256842,
#   'marketChangeOverTime': 0.3045547982256842,
#   'uOpen': 121.45,
#   'uClose': 120.58,
#   'uHigh': 122.04,
#   'uLow': 119.17,
#   'uVolume': 72800787,
#   'fOpen': 121.45,
#   'fClose': 120.58,
#   'fHigh': 122.04,
#   'fLow': 119.17,
#   'fVolume': 72800787,
#   'label': 'May 31, 23',
#   'change': -1.0799999999999983,
#   'changePercent': -0.0089},
#  {'close': 122.77,
#   'high': 123.49,
#   'low': 119.93,
#   'open': 120.69,
#   'priceDate': '2023-06-01',
#   'symbol': 'AMZN',
#   'volume': 54375131,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-01',
#   'updated': 1685723356000,
#   'changeOverTime': 0.3282484041977711,
#   'marketChangeOverTime': 0.3282484041977711,
#   'uOpen': 120.69,
#   'uClose': 122.77,
#   'uHigh': 123.49,
#   'uLow': 119.93,
#   'uVolume': 54375131,
#   'fOpen': 120.69,
#   'fClose': 122.77,
#   'fHigh': 123.49,
#   'fLow': 119.93,
#   'fVolume': 54375131,
#   'label': 'Jun 1, 23',
#   'change': 2.1899999999999977,
#   'changePercent': 0.0182},
#  {'close': 124.25,
#   'high': 126.39,
#   'low': 124.015,
#   'open': 124.92,
#   'priceDate': '2023-06-02',
#   'symbol': 'AMZN',
#   'volume': 61264414,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-02',
#   'updated': 1685755898000,
#   'changeOverTime': 0.34426052147571123,
#   'marketChangeOverTime': 0.34426052147571123,
#   'uOpen': 124.92,
#   'uClose': 124.25,
#   'uHigh': 126.39,
#   'uLow': 124.015,
#   'uVolume': 61264414,
#   'fOpen': 124.92,
#   'fClose': 124.25,
#   'fHigh': 126.39,
#   'fLow': 124.015,
#   'fVolume': 61264414,
#   'label': 'Jun 2, 23',
#   'change': 1.480000000000004,
#   'changePercent': 0.0121},
#  {'close': 125.3,
#   'high': 125.8,
#   'low': 123.03,
#   'open': 123.36,
#   'priceDate': '2023-06-05',
#   'symbol': 'AMZN',
#   'volume': 47950128,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-05',
#   'updated': 1686013238000,
#   'changeOverTime': 0.35562046954452003,
#   'marketChangeOverTime': 0.35562046954452003,
#   'uOpen': 123.36,
#   'uClose': 125.3,
#   'uHigh': 125.8,
#   'uLow': 123.03,
#   'uVolume': 47950128,
#   'fOpen': 123.36,
#   'fClose': 125.3,
#   'fHigh': 125.8,
#   'fLow': 123.03,
#   'fVolume': 47950128,
#   'label': 'Jun 5, 23',
#   'change': 1.0499999999999972,
#   'changePercent': 0.0085},
#  {'close': 126.61,
#   'high': 127.4,
#   'low': 125,
#   'open': 125.07,
#   'priceDate': '2023-06-06',
#   'symbol': 'AMZN',
#   'volume': 45695212,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-06',
#   'updated': 1686103262000,
#   'changeOverTime': 0.3697933571351292,
#   'marketChangeOverTime': 0.3697933571351292,
#   'uOpen': 125.07,
#   'uClose': 126.61,
#   'uHigh': 127.4,
#   'uLow': 125,
#   'uVolume': 45695212,
#   'fOpen': 125.07,
#   'fClose': 126.61,
#   'fHigh': 127.4,
#   'fLow': 125,
#   'fVolume': 45695212,
#   'label': 'Jun 6, 23',
#   'change': 1.3100000000000023,
#   'changePercent': 0.0105},
#  {'close': 121.23,
#   'high': 127.365,
#   'low': 120.63,
#   'open': 127.01,
#   'priceDate': '2023-06-07',
#   'symbol': 'AMZN',
#   'volume': 95663275,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-07',
#   'updated': 1686186026000,
#   'changeOverTime': 0.311587147030185,
#   'marketChangeOverTime': 0.311587147030185,
#   'uOpen': 127.01,
#   'uClose': 121.23,
#   'uHigh': 127.365,
#   'uLow': 120.63,
#   'uVolume': 95663275,
#   'fOpen': 127.01,
#   'fClose': 121.23,
#   'fHigh': 127.365,
#   'fLow': 120.63,
#   'fVolume': 95663275,
#   'label': 'Jun 7, 23',
#   'change': -5.3799999999999955,
#   'changePercent': -0.0425},
#  {'close': 124.25,
#   'high': 125.625,
#   'low': 122.2579,
#   'open': 123.01,
#   'priceDate': '2023-06-08',
#   'symbol': 'AMZN',
#   'volume': 62159270,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-08',
#   'updated': 1686272427000,
#   'changeOverTime': 0.34426052147571123,
#   'marketChangeOverTime': 0.34426052147571123,
#   'uOpen': 123.01,
#   'uClose': 124.25,
#   'uHigh': 125.625,
#   'uLow': 122.2579,
#   'uVolume': 62159270,
#   'fOpen': 123.01,
#   'fClose': 124.25,
#   'fHigh': 125.625,
#   'fLow': 122.2579,
#   'fVolume': 62159270,
#   'label': 'Jun 8, 23',
#   'change': 3.019999999999996,
#   'changePercent': 0.0249},
#  {'close': 123.43,
#   'high': 125.8,
#   'low': 123.19,
#   'open': 124.08,
#   'priceDate': '2023-06-09',
#   'symbol': 'AMZN',
#   'volume': 51396018,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-09',
#   'updated': 1686360624000,
#   'changeOverTime': 0.33538894298387967,
#   'marketChangeOverTime': 0.33538894298387967,
#   'uOpen': 124.08,
#   'uClose': 123.43,
#   'uHigh': 125.8,
#   'uLow': 123.19,
#   'uVolume': 51396018,
#   'fOpen': 124.08,
#   'fClose': 123.43,
#   'fHigh': 125.8,
#   'fLow': 123.19,
#   'fVolume': 51396018,
#   'label': 'Jun 9, 23',
#   'change': -0.8199999999999932,
#   'changePercent': -0.0066},
#  {'close': 126.57,
#   'high': 126.78,
#   'low': 123.53,
#   'open': 124.02,
#   'priceDate': '2023-06-12',
#   'symbol': 'AMZN',
#   'volume': 51473376,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-12',
#   'updated': 1686618041000,
#   'changeOverTime': 0.3693605972086983,
#   'marketChangeOverTime': 0.3693605972086983,
#   'uOpen': 124.02,
#   'uClose': 126.57,
#   'uHigh': 126.78,
#   'uLow': 123.53,
#   'uVolume': 51473376,
#   'fOpen': 124.02,
#   'fClose': 126.57,
#   'fHigh': 126.78,
#   'fLow': 123.53,
#   'fVolume': 51473376,
#   'label': 'Jun 12, 23',
#   'change': 3.1399999999999864,
#   'changePercent': 0.0254},
#  {'close': 126.66,
#   'high': 128.41,
#   'low': 125.18,
#   'open': 128.12,
#   'priceDate': '2023-06-13',
#   'symbol': 'AMZN',
#   'volume': 50564785,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-13',
#   'updated': 1686704430000,
#   'changeOverTime': 0.37033430704316767,
#   'marketChangeOverTime': 0.37033430704316767,
#   'uOpen': 128.12,
#   'uClose': 126.66,
#   'uHigh': 128.41,
#   'uLow': 125.18,
#   'uVolume': 50564785,
#   'fOpen': 128.12,
#   'fClose': 126.66,
#   'fHigh': 128.41,
#   'fLow': 125.18,
#   'fVolume': 50564785,
#   'label': 'Jun 13, 23',
#   'change': 0.09000000000000341,
#   'changePercent': 0.0007},
#  {'close': 126.42,
#   'high': 126.95,
#   'low': 124.12,
#   'open': 126.7,
#   'priceDate': '2023-06-14',
#   'symbol': 'AMZN',
#   'volume': 52422463,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-14',
#   'updated': 1686800157000,
#   'changeOverTime': 0.3677377474845828,
#   'marketChangeOverTime': 0.3677377474845828,
#   'uOpen': 126.7,
#   'uClose': 126.42,
#   'uHigh': 126.95,
#   'uLow': 124.12,
#   'uVolume': 52422463,
#   'fOpen': 126.7,
#   'fClose': 126.42,
#   'fHigh': 126.95,
#   'fLow': 124.12,
#   'fVolume': 52422463,
#   'label': 'Jun 14, 23',
#   'change': -0.23999999999999488,
#   'changePercent': -0.0019},
#  {'close': 127.11,
#   'high': 127.69,
#   'low': 124.32,
#   'open': 125.21,
#   'priceDate': '2023-06-15',
#   'symbol': 'AMZN',
#   'volume': 60458471,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-15',
#   'updated': 1686877295000,
#   'changeOverTime': 0.37520285621551436,
#   'marketChangeOverTime': 0.37520285621551436,
#   'uOpen': 125.21,
#   'uClose': 127.11,
#   'uHigh': 127.69,
#   'uLow': 124.32,
#   'uVolume': 60458471,
#   'fOpen': 125.21,
#   'fClose': 127.11,
#   'fHigh': 127.69,
#   'fLow': 124.32,
#   'fVolume': 60458471,
#   'label': 'Jun 15, 23',
#   'change': 0.6899999999999977,
#   'changePercent': 0.0055},
#  {'close': 125.49,
#   'high': 127.9,
#   'low': 125.3,
#   'open': 127.71,
#   'priceDate': '2023-06-16',
#   'symbol': 'AMZN',
#   'volume': 84247104,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-16',
#   'updated': 1686965429000,
#   'changeOverTime': 0.3576760791950664,
#   'marketChangeOverTime': 0.3576760791950664,
#   'uOpen': 127.71,
#   'uClose': 125.49,
#   'uHigh': 127.9,
#   'uLow': 125.3,
#   'uVolume': 84247104,
#   'fOpen': 127.71,
#   'fClose': 125.49,
#   'fHigh': 127.9,
#   'fLow': 125.3,
#   'fVolume': 84247104,
#   'label': 'Jun 16, 23',
#   'change': -1.6200000000000045,
#   'changePercent': -0.0127},
#  {'close': 125.78,
#   'high': 127.25,
#   'low': 124.5,
#   'open': 124.97,
#   'priceDate': '2023-06-20',
#   'symbol': 'AMZN',
#   'volume': 56930122,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-20',
#   'updated': 1687309222000,
#   'changeOverTime': 0.36081358866168983,
#   'marketChangeOverTime': 0.36081358866168983,
#   'uOpen': 124.97,
#   'uClose': 125.78,
#   'uHigh': 127.25,
#   'uLow': 124.5,
#   'uVolume': 56930122,
#   'fOpen': 124.97,
#   'fClose': 125.78,
#   'fHigh': 127.25,
#   'fLow': 124.5,
#   'fVolume': 56930122,
#   'label': 'Jun 20, 23',
#   'change': 0.29000000000000625,
#   'changePercent': 0.0023},
#  {'close': 124.83,
#   'high': 126.73,
#   'low': 123.85,
#   'open': 125.64,
#   'priceDate': '2023-06-21',
#   'symbol': 'AMZN',
#   'volume': 52137670,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-21',
#   'updated': 1687395722000,
#   'changeOverTime': 0.350535540408958,
#   'marketChangeOverTime': 0.350535540408958,
#   'uOpen': 125.64,
#   'uClose': 124.83,
#   'uHigh': 126.73,
#   'uLow': 123.85,
#   'uVolume': 52137670,
#   'fOpen': 125.64,
#   'fClose': 124.83,
#   'fHigh': 126.73,
#   'fLow': 123.85,
#   'fVolume': 52137670,
#   'label': 'Jun 21, 23',
#   'change': -0.9500000000000028,
#   'changePercent': -0.0076},
#  {'close': 130.15,
#   'high': 130.33,
#   'low': 125.14,
#   'open': 125.31,
#   'priceDate': '2023-06-22',
#   'symbol': 'AMZN',
#   'volume': 90354572,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-22',
#   'updated': 1687482027000,
#   'changeOverTime': 0.40809261062425617,
#   'marketChangeOverTime': 0.40809261062425617,
#   'uOpen': 125.31,
#   'uClose': 130.15,
#   'uHigh': 130.33,
#   'uLow': 125.14,
#   'uVolume': 90354572,
#   'fOpen': 125.31,
#   'fClose': 130.15,
#   'fHigh': 130.33,
#   'fLow': 125.14,
#   'fVolume': 90354572,
#   'label': 'Jun 22, 23',
#   'change': 5.320000000000007,
#   'changePercent': 0.0426},
#  {'close': 129.33,
#   'high': 130.84,
#   'low': 128.28,
#   'open': 129.11,
#   'priceDate': '2023-06-23',
#   'symbol': 'AMZN',
#   'volume': 71927776,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-23',
#   'updated': 1687570221000,
#   'changeOverTime': 0.39922103213242455,
#   'marketChangeOverTime': 0.39922103213242455,
#   'uOpen': 129.11,
#   'uClose': 129.33,
#   'uHigh': 130.84,
#   'uLow': 128.28,
#   'uVolume': 71927776,
#   'fOpen': 129.11,
#   'fClose': 129.33,
#   'fHigh': 130.84,
#   'fLow': 128.28,
#   'fVolume': 71927776,
#   'label': 'Jun 23, 23',
#   'change': -0.8199999999999932,
#   'changePercent': -0.0063},
#  {'close': 127.33,
#   'high': 131.49,
#   'low': 127.1,
#   'open': 129.33,
#   'priceDate': '2023-06-26',
#   'symbol': 'AMZN',
#   'volume': 59989317,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-26',
#   'updated': 1687829433000,
#   'changeOverTime': 0.3775830358108838,
#   'marketChangeOverTime': 0.3775830358108838,
#   'uOpen': 129.33,
#   'uClose': 127.33,
#   'uHigh': 131.49,
#   'uLow': 127.1,
#   'uVolume': 59989317,
#   'fOpen': 129.33,
#   'fClose': 127.33,
#   'fHigh': 131.49,
#   'fLow': 127.1,
#   'fVolume': 59989317,
#   'label': 'Jun 26, 23',
#   'change': -2.000000000000014,
#   'changePercent': -0.0155},
#  {'close': 129.18,
#   'high': 130.085,
#   'low': 127.55,
#   'open': 128.63,
#   'priceDate': '2023-06-27',
#   'symbol': 'AMZN',
#   'volume': 46801008,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-27',
#   'updated': 1687914037000,
#   'changeOverTime': 0.39759818240830896,
#   'marketChangeOverTime': 0.39759818240830896,
#   'uOpen': 128.63,
#   'uClose': 129.18,
#   'uHigh': 130.085,
#   'uLow': 127.55,
#   'uVolume': 46801008,
#   'fOpen': 128.63,
#   'fClose': 129.18,
#   'fHigh': 130.085,
#   'fLow': 127.55,
#   'fVolume': 46801008,
#   'label': 'Jun 27, 23',
#   'change': 1.8500000000000085,
#   'changePercent': 0.0145},
#  {'close': 129.04,
#   'high': 131.48,
#   'low': 128.44,
#   'open': 128.94,
#   'priceDate': '2023-06-28',
#   'symbol': 'AMZN',
#   'volume': 52149512,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-28',
#   'updated': 1688000427000,
#   'changeOverTime': 0.39608352266580094,
#   'marketChangeOverTime': 0.39608352266580094,
#   'uOpen': 128.94,
#   'uClose': 129.04,
#   'uHigh': 131.48,
#   'uLow': 128.44,
#   'uVolume': 52149512,
#   'fOpen': 128.94,
#   'fClose': 129.04,
#   'fHigh': 131.48,
#   'fLow': 128.44,
#   'fVolume': 52149512,
#   'label': 'Jun 28, 23',
#   'change': -0.14000000000001478,
#   'changePercent': -0.0011},
#  {'close': 127.9,
#   'high': 129.26,
#   'low': 127.255,
#   'open': 128.77,
#   'priceDate': '2023-06-29',
#   'symbol': 'AMZN',
#   'volume': 40760959,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-29',
#   'updated': 1688090464000,
#   'changeOverTime': 0.38374986476252293,
#   'marketChangeOverTime': 0.38374986476252293,
#   'uOpen': 128.77,
#   'uClose': 127.9,
#   'uHigh': 129.26,
#   'uLow': 127.255,
#   'uVolume': 40760959,
#   'fOpen': 128.77,
#   'fClose': 127.9,
#   'fHigh': 129.26,
#   'fLow': 127.255,
#   'fVolume': 40760959,
#   'label': 'Jun 29, 23',
#   'change': -1.1399999999999864,
#   'changePercent': -0.0088},
#  {'close': 130.36,
#   'high': 131.245,
#   'low': 128.95,
#   'open': 129.47,
#   'priceDate': '2023-06-30',
#   'symbol': 'AMZN',
#   'volume': 54350684,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2023-06-30',
#   'updated': 1688179056000,
#   'changeOverTime': 0.410364600238018,
#   'marketChangeOverTime': 0.410364600238018,
#   'uOpen': 129.47,
#   'uClose': 130.36,
#   'uHigh': 131.245,
#   'uLow': 128.95,
#   'uVolume': 54350684,
#   'fOpen': 129.47,
#   'fClose': 130.36,
#   'fHigh': 131.245,
#   'fLow': 128.95,
#   'fVolume': 54350684,
#   'label': 'Jun 30, 23',
#   'change': 2.460000000000008,
# ...
#   'changeOverTime': 0.7232500270474953,
#   'marketChangeOverTime': 0.7232500270474953,
#   'uOpen': 155.87,
#   'uClose': 159.28,
#   'uHigh': 159.76,
#   'uLow': 155.62,
#   'uVolume': 76542419,
#   'fOpen': 155.87,
#   'fClose': 159.28,
#   'fHigh': 159.76,
#   'fLow': 155.62,
#   'fVolume': 76542419,
#   'label': 'Feb 1, 24',
#   'change': 4.0800000000000125,
#   'changePercent': 0.0263},
#  {'close': 171.81,
#   'high': 172.5,
#   'low': 167.33,
#   'open': 169.19,
#   'priceDate': '2024-02-02',
#   'symbol': 'AMZN',
#   'volume': 117218313,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-02',
#   'updated': 1706927455000,
#   'changeOverTime': 0.8588120740019473,
#   'marketChangeOverTime': 0.8588120740019473,
#   'uOpen': 169.19,
#   'uClose': 171.81,
#   'uHigh': 172.5,
#   'uLow': 167.33,
#   'uVolume': 117218313,
#   'fOpen': 169.19,
#   'fClose': 171.81,
#   'fHigh': 172.5,
#   'fLow': 167.33,
#   'fVolume': 117218313,
#   'label': 'Feb 2, 24',
#   'change': 12.530000000000001,
#   'changePercent': 0.0787},
#  {'close': 170.31,
#   'high': 170.55,
#   'low': 167.7,
#   'open': 170.2,
#   'priceDate': '2024-02-05',
#   'symbol': 'AMZN',
#   'volume': 55081297,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-05',
#   'updated': 1707186786000,
#   'changeOverTime': 0.8425835767607919,
#   'marketChangeOverTime': 0.8425835767607919,
#   'uOpen': 170.2,
#   'uClose': 170.31,
#   'uHigh': 170.55,
#   'uLow': 167.7,
#   'uVolume': 55081297,
#   'fOpen': 170.2,
#   'fClose': 170.31,
#   'fHigh': 170.55,
#   'fLow': 167.7,
#   'fVolume': 55081297,
#   'label': 'Feb 5, 24',
#   'change': -1.5,
#   'changePercent': -0.0087},
#  {'close': 169.15,
#   'high': 170.71,
#   'low': 167.65,
#   'open': 169.39,
#   'priceDate': '2024-02-06',
#   'symbol': 'AMZN',
#   'volume': 42505518,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-06',
#   'updated': 1707271224000,
#   'changeOverTime': 0.8300335388942983,
#   'marketChangeOverTime': 0.8300335388942983,
#   'uOpen': 169.39,
#   'uClose': 169.15,
#   'uHigh': 170.71,
#   'uLow': 167.65,
#   'uVolume': 42505518,
#   'fOpen': 169.39,
#   'fClose': 169.15,
#   'fHigh': 170.71,
#   'fLow': 167.65,
#   'fVolume': 42505518,
#   'label': 'Feb 6, 24',
#   'change': -1.1599999999999966,
#   'changePercent': -0.0068},
#  {'close': 170.53,
#   'high': 170.88,
#   'low': 168.94,
#   'open': 169.48,
#   'priceDate': '2024-02-07',
#   'symbol': 'AMZN',
#   'volume': 47174060,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-07',
#   'updated': 1707359439000,
#   'changeOverTime': 0.8449637563561613,
#   'marketChangeOverTime': 0.8449637563561613,
#   'uOpen': 169.48,
#   'uClose': 170.53,
#   'uHigh': 170.88,
#   'uLow': 168.94,
#   'uVolume': 47174060,
#   'fOpen': 169.48,
#   'fClose': 170.53,
#   'fHigh': 170.88,
#   'fLow': 168.94,
#   'fVolume': 47174060,
#   'label': 'Feb 7, 24',
#   'change': 1.3799999999999955,
#   'changePercent': 0.0082},
#  {'close': 169.84,
#   'high': 171.43,
#   'low': 168.88,
#   'open': 169.65,
#   'priceDate': '2024-02-08',
#   'symbol': 'AMZN',
#   'volume': 42316454,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-08',
#   'updated': 1707444026000,
#   'changeOverTime': 0.8374986476252299,
#   'marketChangeOverTime': 0.8374986476252299,
#   'uOpen': 169.65,
#   'uClose': 169.84,
#   'uHigh': 171.43,
#   'uLow': 168.88,
#   'uVolume': 42316454,
#   'fOpen': 169.65,
#   'fClose': 169.84,
#   'fHigh': 171.43,
#   'fLow': 168.88,
#   'fVolume': 42316454,
#   'label': 'Feb 8, 24',
#   'change': -0.6899999999999977,
#   'changePercent': -0.004},
#  {'close': 174.45,
#   'high': 175,
#   'low': 170.5803,
#   'open': 170.9,
#   'priceDate': '2024-02-09',
#   'symbol': 'AMZN',
#   'volume': 56985986,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-09',
#   'updated': 1707532235000,
#   'changeOverTime': 0.8873742291463808,
#   'marketChangeOverTime': 0.8873742291463808,
#   'uOpen': 170.9,
#   'uClose': 174.45,
#   'uHigh': 175,
#   'uLow': 170.5803,
#   'uVolume': 56985986,
#   'fOpen': 170.9,
#   'fClose': 174.45,
#   'fHigh': 175,
#   'fLow': 170.5803,
#   'fVolume': 56985986,
#   'label': 'Feb 9, 24',
#   'change': 4.609999999999985,
#   'changePercent': 0.0271},
#  {'close': 172.34,
#   'high': 175.39,
#   'low': 171.54,
#   'open': 174.8,
#   'priceDate': '2024-02-12',
#   'symbol': 'AMZN',
#   'volume': 51050440,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-12',
#   'updated': 1707789622000,
#   'changeOverTime': 0.8645461430271556,
#   'marketChangeOverTime': 0.8645461430271556,
#   'uOpen': 174.8,
#   'uClose': 172.34,
#   'uHigh': 175.39,
#   'uLow': 171.54,
#   'uVolume': 51050440,
#   'fOpen': 174.8,
#   'fClose': 172.34,
#   'fHigh': 175.39,
#   'fLow': 171.54,
#   'fVolume': 51050440,
#   'label': 'Feb 12, 24',
#   'change': -2.109999999999985,
#   'changePercent': -0.0121},
#  {'close': 168.64,
#   'high': 170.95,
#   'low': 165.75,
#   'open': 167.73,
#   'priceDate': '2024-02-13',
#   'symbol': 'AMZN',
#   'volume': 56345122,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-13',
#   'updated': 1707876058000,
#   'changeOverTime': 0.8245158498323052,
#   'marketChangeOverTime': 0.8245158498323052,
#   'uOpen': 167.73,
#   'uClose': 168.64,
#   'uHigh': 170.95,
#   'uLow': 165.75,
#   'uVolume': 56345122,
#   'fOpen': 167.73,
#   'fClose': 168.64,
#   'fHigh': 170.95,
#   'fLow': 165.75,
#   'fVolume': 56345122,
#   'label': 'Feb 13, 24',
#   'change': -3.700000000000017,
#   'changePercent': -0.0215},
#  {'close': 170.98,
#   'high': 171.21,
#   'low': 168.28,
#   'open': 169.21,
#   'priceDate': '2024-02-14',
#   'symbol': 'AMZN',
#   'volume': 42815544,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-14',
#   'updated': 1707962489000,
#   'changeOverTime': 0.8498323055285079,
#   'marketChangeOverTime': 0.8498323055285079,
#   'uOpen': 169.21,
#   'uClose': 170.98,
#   'uHigh': 171.21,
#   'uLow': 168.28,
#   'uVolume': 42815544,
#   'fOpen': 169.21,
#   'fClose': 170.98,
#   'fHigh': 171.21,
#   'fLow': 168.28,
#   'fVolume': 42815544,
#   'label': 'Feb 14, 24',
#   'change': 2.3400000000000034,
#   'changePercent': 0.0139},
#  {'close': 169.8,
#   'high': 171.17,
#   'low': 167.59,
#   'open': 170.58,
#   'priceDate': '2024-02-15',
#   'symbol': 'AMZN',
#   'volume': 49855196,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-15',
#   'updated': 1708048836000,
#   'changeOverTime': 0.8370658876987991,
#   'marketChangeOverTime': 0.8370658876987991,
#   'uOpen': 170.58,
#   'uClose': 169.8,
#   'uHigh': 171.17,
#   'uLow': 167.59,
#   'uVolume': 49855196,
#   'fOpen': 170.58,
#   'fClose': 169.8,
#   'fHigh': 171.17,
#   'fLow': 167.59,
#   'fVolume': 49855196,
#   'label': 'Feb 15, 24',
#   'change': -1.1799999999999784,
#   'changePercent': -0.0069},
#  {'close': 169.51,
#   'high': 170.42,
#   'low': 167.17,
#   'open': 168.74,
#   'priceDate': '2024-02-16',
#   'symbol': 'AMZN',
#   'volume': 48107744,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-16',
#   'updated': 1708137062000,
#   'changeOverTime': 0.8339283782321755,
#   'marketChangeOverTime': 0.8339283782321755,
#   'uOpen': 168.74,
#   'uClose': 169.51,
#   'uHigh': 170.42,
#   'uLow': 167.17,
#   'uVolume': 48107744,
#   'fOpen': 168.74,
#   'fClose': 169.51,
#   'fHigh': 170.42,
#   'fLow': 167.17,
#   'fVolume': 48107744,
#   'label': 'Feb 16, 24',
#   'change': -0.29000000000002046,
#   'changePercent': -0.0017},
#  {'close': 167.08,
#   'high': 168.71,
#   'low': 165.74,
#   'open': 167.83,
#   'priceDate': '2024-02-20',
#   'symbol': 'AMZN',
#   'volume': 41980326,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-20',
#   'updated': 1708480834000,
#   'changeOverTime': 0.8076382127015038,
#   'marketChangeOverTime': 0.8076382127015038,
#   'uOpen': 167.83,
#   'uClose': 167.08,
#   'uHigh': 168.71,
#   'uLow': 165.74,
#   'uVolume': 41980326,
#   'fOpen': 167.83,
#   'fClose': 167.08,
#   'fHigh': 168.71,
#   'fLow': 165.74,
#   'fVolume': 41980326,
#   'label': 'Feb 20, 24',
#   'change': -2.4299999999999784,
#   'changePercent': -0.0143},
#  {'close': 168.59,
#   'high': 170.23,
#   'low': 167.14,
#   'open': 168.94,
#   'priceDate': '2024-02-21',
#   'symbol': 'AMZN',
#   'volume': 44575623,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-21',
#   'updated': 1708570882000,
#   'changeOverTime': 0.8239748999242669,
#   'marketChangeOverTime': 0.8239748999242669,
#   'uOpen': 168.94,
#   'uClose': 168.59,
#   'uHigh': 170.23,
#   'uLow': 167.14,
#   'uVolume': 44575623,
#   'fOpen': 168.94,
#   'fClose': 168.59,
#   'fHigh': 170.23,
#   'fLow': 167.14,
#   'fVolume': 44575623,
#   'label': 'Feb 21, 24',
#   'change': 1.509999999999991,
#   'changePercent': 0.009},
#  {'close': 174.58,
#   'high': 174.8,
#   'low': 171.77,
#   'open': 173.1,
#   'priceDate': '2024-02-22',
#   'symbol': 'AMZN',
#   'volume': 55392354,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-22',
#   'updated': 1708653675000,
#   'changeOverTime': 0.8887806989072812,
#   'marketChangeOverTime': 0.8887806989072812,
#   'uOpen': 173.1,
#   'uClose': 174.58,
#   'uHigh': 174.8,
#   'uLow': 171.77,
#   'uVolume': 55392354,
#   'fOpen': 173.1,
#   'fClose': 174.58,
#   'fHigh': 174.8,
#   'fLow': 171.77,
#   'fVolume': 55392354,
#   'label': 'Feb 22, 24',
#   'change': 5.990000000000009,
#   'changePercent': 0.0355},
#  {'close': 174.99,
#   'high': 175.75,
#   'low': 173.7,
#   'open': 174.28,
#   'priceDate': '2024-02-23',
#   'symbol': 'AMZN',
#   'volume': 59715243,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-23',
#   'updated': 1708741844000,
#   'changeOverTime': 0.893216488153197,
#   'marketChangeOverTime': 0.893216488153197,
#   'uOpen': 174.28,
#   'uClose': 174.99,
#   'uHigh': 175.75,
#   'uLow': 173.7,
#   'uVolume': 59715243,
#   'fOpen': 174.28,
#   'fClose': 174.99,
#   'fHigh': 175.75,
#   'fLow': 173.7,
#   'fVolume': 59715243,
#   'label': 'Feb 23, 24',
#   'change': 0.4099999999999966,
#   'changePercent': 0.0023},
#  {'close': 174.73,
#   'high': 176.37,
#   'low': 174.26,
#   'open': 175.7,
#   'priceDate': '2024-02-26',
#   'symbol': 'AMZN',
#   'volume': 44368614,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-26',
#   'updated': 1708999246000,
#   'changeOverTime': 0.8904035486313965,
#   'marketChangeOverTime': 0.8904035486313965,
#   'uOpen': 175.7,
#   'uClose': 174.73,
#   'uHigh': 176.37,
#   'uLow': 174.26,
#   'uVolume': 44368614,
#   'fOpen': 175.7,
#   'fClose': 174.73,
#   'fHigh': 176.37,
#   'fLow': 174.26,
#   'fVolume': 44368614,
#   'label': 'Feb 26, 24',
#   'change': -0.2600000000000193,
#   'changePercent': -0.0015},
#  {'close': 173.54,
#   'high': 174.62,
#   'low': 172.86,
#   'open': 174.075,
#   'priceDate': '2024-02-27',
#   'symbol': 'AMZN',
#   'volume': 31141732,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-27',
#   'updated': 1709089239000,
#   'changeOverTime': 0.8775289408200798,
#   'marketChangeOverTime': 0.8775289408200798,
#   'uOpen': 174.075,
#   'uClose': 173.54,
#   'uHigh': 174.62,
#   'uLow': 172.86,
#   'uVolume': 31141732,
#   'fOpen': 174.075,
#   'fClose': 173.54,
#   'fHigh': 174.62,
#   'fLow': 172.86,
#   'fVolume': 31141732,
#   'label': 'Feb 27, 24',
#   'change': -1.1899999999999977,
#   'changePercent': -0.0068},
#  {'close': 173.16,
#   'high': 174.05,
#   'low': 172.27,
#   'open': 172.44,
#   'priceDate': '2024-02-28',
#   'symbol': 'AMZN',
#   'volume': 28180482,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-28',
#   'updated': 1709172069000,
#   'changeOverTime': 0.8734177215189871,
#   'marketChangeOverTime': 0.8734177215189871,
#   'uOpen': 172.44,
#   'uClose': 173.16,
#   'uHigh': 174.05,
#   'uLow': 172.27,
#   'uVolume': 28180482,
#   'fOpen': 172.44,
#   'fClose': 173.16,
#   'fHigh': 174.05,
#   'fLow': 172.27,
#   'fVolume': 28180482,
#   'label': 'Feb 28, 24',
#   'change': -0.37999999999999545,
#   'changePercent': -0.0022},
#  {'close': 176.76,
#   'high': 177.22,
#   'low': 172.85,
#   'open': 173.01,
#   'priceDate': '2024-02-29',
#   'symbol': 'AMZN',
#   'volume': 53805359,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-02-29',
#   'updated': 1709258441000,
#   'changeOverTime': 0.9123661148977602,
#   'marketChangeOverTime': 0.9123661148977602,
#   'uOpen': 173.01,
#   'uClose': 176.76,
#   'uHigh': 177.22,
#   'uLow': 172.85,
#   'uVolume': 53805359,
#   'fOpen': 173.01,
#   'fClose': 176.76,
#   'fHigh': 177.22,
#   'fLow': 172.85,
#   'fVolume': 53805359,
#   'label': 'Feb 29, 24',
#   'change': 3.5999999999999943,
#   'changePercent': 0.0208},
#  {'close': 178.22,
#   'high': 178.725,
#   'low': 176.07,
#   'open': 176.75,
#   'priceDate': '2024-03-01',
#   'symbol': 'AMZN',
#   'volume': 31981152,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-03-01',
#   'updated': 1709350255000,
#   'changeOverTime': 0.9281618522124849,
#   'marketChangeOverTime': 0.9281618522124849,
#   'uOpen': 176.75,
#   'uClose': 178.22,
#   'uHigh': 178.725,
#   'uLow': 176.07,
#   'uVolume': 31981152,
#   'fOpen': 176.75,
#   'fClose': 178.22,
#   'fHigh': 178.725,
#   'fLow': 176.07,
#   'fVolume': 31981152,
#   'label': 'Mar 1, 24',
#   'change': 1.460000000000008,
#   'changePercent': 0.0083},
#  {'close': 177.58,
#   'high': 180.14,
#   'low': 177.49,
#   'open': 177.53,
#   'priceDate': '2024-03-04',
#   'symbol': 'AMZN',
#   'volume': 37381520,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-03-04',
#   'updated': 1709604034000,
#   'changeOverTime': 0.9212376933895922,
#   'marketChangeOverTime': 0.9212376933895922,
#   'uOpen': 177.53,
#   'uClose': 177.58,
#   'uHigh': 180.14,
#   'uLow': 177.49,
#   'uVolume': 37381520,
#   'fOpen': 177.53,
#   'fClose': 177.58,
#   'fHigh': 180.14,
#   'fLow': 177.49,
#   'fVolume': 37381520,
#   'label': 'Mar 4, 24',
#   'change': -0.6399999999999864,
#   'changePercent': -0.0036},
#  {'close': 174.12,
#   'high': 176.93,
#   'low': 173.303,
#   'open': 176.93,
#   'priceDate': '2024-03-05',
#   'symbol': 'AMZN',
#   'volume': 37228343,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-03-05',
#   'updated': 1709692209000,
#   'changeOverTime': 0.8838039597533267,
#   'marketChangeOverTime': 0.8838039597533267,
#   'uOpen': 176.93,
#   'uClose': 174.12,
#   'uHigh': 176.93,
#   'uLow': 173.303,
#   'uVolume': 37228343,
#   'fOpen': 176.93,
#   'fClose': 174.12,
#   'fHigh': 176.93,
#   'fLow': 173.303,
#   'fVolume': 37228343,
#   'label': 'Mar 5, 24',
#   'change': -3.460000000000008,
#   'changePercent': -0.0195},
#  {'close': 173.51,
#   'high': 176.46,
#   'low': 173.26,
#   'open': 175.54,
#   'priceDate': '2024-03-06',
#   'symbol': 'AMZN',
#   'volume': 32090926,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-03-06',
#   'updated': 1709776809000,
#   'changeOverTime': 0.8772043708752567,
#   'marketChangeOverTime': 0.8772043708752567,
#   'uOpen': 175.54,
#   'uClose': 173.51,
#   'uHigh': 176.46,
#   'uLow': 173.26,
#   'uVolume': 32090926,
#   'fOpen': 175.54,
#   'fClose': 173.51,
#   'fHigh': 176.46,
#   'fLow': 173.26,
#   'fVolume': 32090926,
#   'label': 'Mar 6, 24',
#   'change': -0.6100000000000136,
#   'changePercent': -0.0035},
#  {'close': 176.82,
#   'high': 177.99,
#   'low': 173.72,
#   'open': 174.83,
#   'priceDate': '2024-03-07',
#   'symbol': 'AMZN',
#   'volume': 34063283,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-03-07',
#   'updated': 1709863219000,
#   'changeOverTime': 0.9130152547874064,
#   'marketChangeOverTime': 0.9130152547874064,
#   'uOpen': 174.83,
#   'uClose': 176.82,
#   'uHigh': 177.99,
#   'uLow': 173.72,
#   'uVolume': 34063283,
#   'fOpen': 174.83,
#   'fClose': 176.82,
#   'fHigh': 177.99,
#   'fLow': 173.72,
#   'fVolume': 34063283,
#   'label': 'Mar 7, 24',
#   'change': 3.3100000000000023,
#   'changePercent': 0.0191},
#  {'close': 175.35,
#   'high': 178.785,
#   'low': 174.33,
#   'open': 176.44,
#   'priceDate': '2024-03-08',
#   'symbol': 'AMZN',
#   'volume': 37893242,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AMZN',
#   'subkey': '',
#   'date': '2024-03-08',
#   'updated': 1709951456000,
#   'changeOverTime': 0.8971113274910741,
#   'marketChangeOverTime': 0.8971113274910741,
#   'uOpen': 176.44,
#   'uClose': 175.35,
#   'uHigh': 178.785,
#   'uLow': 174.33,
#   'uVolume': 37893242,
#   'fOpen': 176.44,
#   'fClose': 175.35,
#   'fHigh': 178.785,
#   'fLow': 174.33,
#   'fVolume': 37893242,
#   'label': 'Mar 8, 24',
#   'change': -1.4699999999999989,
#   'changePercent': -0.0083}]

# %%
url3 = "http://iex.lewagon.com/stable/stock/fb/quote/marketCap"
fb_mkt_cap = requests.get(url3).json()

fb_mkt_cap
# Out:
# 561210585170

# %%
url4 = "http://iex.lewagon.com/stable/stock/aapl/income/"
appl_financials = requests.get(url4).json()

appl_financials['income'][0]['researchAndDevelopment']

# appl_financials = pd.DataFrame(requests.get(url4).json()['income'])
# appl_financials[['researchAndDevelopment']]
# Out:
# 7696000000

# %%
url5 = "http://iex.lewagon.com/stable/stock/tsla/news/last/"
tsla_news = requests.get(url5).json()

tsla_news
# Out:
# [{'datetime': 1710123053000,
#   'headline': "Cathie Wood''s Ark Invest Sees $28 Trillion Opportunity In AI: Tesla, Drones And More",
#   'source': 'Benzinga',
#   'url': 'https://cloud.iexapis.com/v1/news/article/2CeR8Etvp1rTW4yefeZuDAD3GWmDGIodrziTSEoeazq2',
#   'summary': 'The future of artificial intelligence (AI) is set to bring about a significant financial impact, with Cathie Wood’ s Ark Invest analyst Tasha Keeney estimating a $28 trillion opportunity. Keeney has identified key sectors that stand to benefit, including Tesla Inc (NASDAQ: TSLA ) and drone technology. What Happened : Keeney, the director of investment analysis and institutional strategies at Ark Invest, has projected that the equity market capitalization linked to innovation will soar to $220 trillion by the end of the decade, largely driven by AI, reported CNBC on Sunday. Ark Invest, known for its focus on innovation, has investments in various sectors, including autonomous vehicles, drones, robotics, energy storage, 3D printing, and space exploration through its Ark Autonomous Tech & Robotics ETF (ARKQ). "Autonomous cars are already driving in major cities today across the globe. We think that in the next 10 years, that will scale up. I think that opportunity alone could be worth $28 trillion in enterprise value because this will be very disruptive," she told CNBC\'\'s "Street Signs Asia." She pointed to Tesla as a standout company in this …',
#   'related': 'TL0-GF,TL0-GM,TL0-GY,TL0-GH,TL0-GS,TL0-GI,TL0-GD,TL0-GB,TSLA,TSLA-QH,ARKQ,ARKQ',
#   'image': 'https://cloud.iexapis.com/v1/news/image/2CeR8Etvp1rTW4yefeZuDAD3GWmDGIodrziTSEoeazq2',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1710120674000,
#   'headline': "Germany: Protest against Tesla plans to expand ''Gigafactory''",
#   'source': 'Times of Oman',
#   'url': 'https://cloud.iexapis.com/v1/news/article/26t6Nzv5bz3ssCT8nuUB0xbgnJvoKQhXXqdQCgbx8WzD',
#   'summary': "Berlin: Hundreds of environmental activists protested Sunday against the expansion of electric carmaker Tesla''s factory outside of Berlin.The demonstration…",
#   'related': 'TL0-GF,TL0-GM,TL0-GY,TL0-GH,TL0-GS,TL0-GI,TL0-GD,TL0-GB,TSLA,TSLA-QH',
#   'image': 'https://cloud.iexapis.com/v1/news/image/26t6Nzv5bz3ssCT8nuUB0xbgnJvoKQhXXqdQCgbx8WzD',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1710111625000,
#   'headline': "OpenAI Revealed That Elon Musk Left Company After It Declined To Merge With Tesla in This Week''s Tech Roundup",
#   'source': 'EIN News Tech',
#   'url': 'https://cloud.iexapis.com/v1/news/article/1mbu9MLs4xDt2PKhuTqL70VaMB7GqeQhGmFzH4GaUgtr',
#   'summary': 'This week, the tech industry turned its focus to … has rounded up the top tech stories of the week so …',
#   'related': 'TL0-GF,TL0-GM,TL0-GY,TL0-GH,TL0-GS,TL0-GI,TL0-GD,TL0-GB,TSLA,TSLA-QH',
#   'image': 'https://cloud.iexapis.com/v1/news/image/1mbu9MLs4xDt2PKhuTqL70VaMB7GqeQhGmFzH4GaUgtr',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1710090612000,
#   'headline': 'Activists protest Tesla plant expansion in Germany',
#   'source': 'YenComGh',
#   'url': 'https://cloud.iexapis.com/v1/news/article/rtdqszJv7AzKV5a5tWIDPUEVHaST47KY9w7N75dvLgu',
#   'summary': 'Several hundred people demonstrated Sunday against plans by Tesla to expand its electric car factory near Berlin, citing environmental concerns. A smaller counter-protest was held Sunday in support of the Tesla factory, with participants citing economic benefits for the region.',
#   'related': 'TL0-GF,TL0-GM,TL0-GY,TL0-GH,TL0-GS,TL0-GI,TL0-GD,TL0-GB,TSLA,TSLA-QH',
#   'image': 'https://cloud.iexapis.com/v1/news/image/rtdqszJv7AzKV5a5tWIDPUEVHaST47KY9w7N75dvLgu',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1710090545000,
#   'headline': 'Activists protest Tesla plant expansion in Germany',
#   'source': 'RTL Today',
#   'url': 'https://cloud.iexapis.com/v1/news/article/1rf5sGqQ9T50VtrxhWDNPA4FryP67JhsGpaEzxzkwkh6',
#   'summary': '…',
#   'related': 'TL0-GF,TL0-GM,TL0-GY,TL0-GH,TL0-GS,TL0-GI,TL0-GD,TL0-GB,TSLA,TSLA-QH',
#   'image': 'https://cloud.iexapis.com/v1/news/image/1rf5sGqQ9T50VtrxhWDNPA4FryP67JhsGpaEzxzkwkh6',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1710089208000,
#   'headline': 'India wont tailor policy for Tesla',
#   'source': 'Millennium Post',
#   'url': 'https://cloud.iexapis.com/v1/news/article/TggFzkKtTKhTAIscS9rEtQQsbnMcFTsaMmCDCz3D5v5',
#   'summary': 'New Delhi: India will not tailor its policies to suit US EV maker Tesla, and its laws and tariff rules will be formulated to attract all-electric vehicle manufacturers from across the world to set up…',
#   'related': 'TL0-GF,TL0-GM,TL0-GY,TL0-GH,TL0-GS,TL0-GI,TL0-GD,TL0-GB,TSLA,TSLA-QH',
#   'image': 'https://cloud.iexapis.com/v1/news/image/TggFzkKtTKhTAIscS9rEtQQsbnMcFTsaMmCDCz3D5v5',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1710077633000,
#   'headline': 'Tesla’s Berlin plant to restart after fire',
#   'source': 'BusinessLIVE',
#   'url': 'https://cloud.iexapis.com/v1/news/article/2WvWz2NpTwEtoqS7JLQD4REsHCH9vuFyEKmkzn2zsfC5',
#   'summary': 'Police probe incident as an arson attack, and see a far-left group’s letter claiming responsibility as authentic',
#   'related': 'TL0-GF,TL0-GM,TL0-GY,TL0-GH,TL0-GS,TL0-GI,TL0-GD,TL0-GB,TSLA,TSLA-QH',
#   'image': 'https://cloud.iexapis.com/v1/news/image/2WvWz2NpTwEtoqS7JLQD4REsHCH9vuFyEKmkzn2zsfC5',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1710076250000,
#   'headline': 'Tesla And These Big Losers Are Far From Magnificent',
#   'source': "Investor''s Business Daily",
#   'url': 'https://cloud.iexapis.com/v1/news/article/naH3Lq4YAmoaMNNuXa4zto37S',
#   'summary': "isn''t just the worst performer in the Magnificent Seven in 2024, it''s the biggest loser in the S&P 500 index",
#   'related': 'TL0-GF,TL0-GM,TL0-GY,TL0-GH,TL0-GS,TL0-GI,TL0-GD,TL0-GB,TSLA,TSLA-QH',
#   'image': 'https://cloud.iexapis.com/v1/news/image/naH3Lq4YAmoaMNNuXa4zto37S',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1710076023000,
#   'headline': 'Elon Musk’s Connection to OpenAI Unveiled: A Bid to Salvage Tesla',
#   'source': 'Cryptopolitan',
#   'url': 'https://cloud.iexapis.com/v1/news/article/f2R7j63Q4MsMI19pVmkSjsMcSH2qboCCggypxT33MMe',
#   'summary': 'In a recent revelation, it has come to light that Elon Musk’s involvement with OpenAI was more than just a strategic business move; it was potentially a lifeline for Tesla during a tumultuous period. The intricate web of Musk’s intentions, as revealed through emails and communications, suggests a desperate bid to rescue Tesla, intertwined with […]',
#   'related': 'TL0-GF,TL0-GM,TL0-GY,TL0-GH,TL0-GS,TL0-GI,TL0-GD,TL0-GB,TSLA,TSLA-QH',
#   'image': 'https://cloud.iexapis.com/v1/news/image/f2R7j63Q4MsMI19pVmkSjsMcSH2qboCCggypxT33MMe',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1710075795000,
#   'headline': 'BTC to Target $70,000? ETF Surge & Tesla Buys Fuel Rally',
#   'source': 'BestNews.com',
#   'url': 'https://cloud.iexapis.com/v1/news/article/2oKn8tBM2g9pBbzAyGImvvy3KgpSA1W3M5fRwHRM6jJM',
#   'summary': 'Last updated: March 8, 2024 02:37 EST | 3 min read During the Asian session, Bitcoin price is trading at $67,500 with a near 1% increase on Friday. This growth parallels the significant strides within the Bitcoin ETF sector, exemplified by the Volatility Shares 2X Bitcoin Strategy ETF (BITX) nearing a milestone of $1 billion … The post BTC to Target $70,000? ETF Surge & Tesla Buys Fuel Rally appeared first on Best News .',
#   'related': 'TL0-GF,TL0-GM,TL0-GY,TL0-GH,TL0-GS,TL0-GI,TL0-GD,TL0-GB,TSLA,TSLA-QH',
#   'image': 'https://cloud.iexapis.com/v1/news/image/2oKn8tBM2g9pBbzAyGImvvy3KgpSA1W3M5fRwHRM6jJM',
#   'lang': 'en',
#   'hasPaywall': False}]

# %%
url6 = "http://iex.lewagon.com/stable/stock/market/sector-performance"
sector_performances = pd.DataFrame(requests.get(url6).json())

sector_performances[sector_performances['name']=='Energy']
# Out:
#      type    name symbol  performance    lastUpdated
# 1  sector  Energy    XLE      0.00353  1709931600003

# %%
api_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
stocks = ['goog', 'fb', 'amzn', 'aapl', 'meli']
stocks_data = pd.DataFrame(columns=['date']+stocks)
for stock in stocks:
    url = f"http://iex.lewagon.com/stable/stock/{stock}/chart/1y"
    api_data = pd.DataFrame(requests.get(url).json())
    stocks_data[['date', stock]] = api_data[['date', 'close']]
    
stocks_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [31], line 6
#       4     url = f"http://iex.lewagon.com/stable/stock/{stock}/chart/1y"
#       5     api_data = pd.DataFrame(requests.get(url).json())
# ----> 6     stocks_data[['date', stock]] = api_data[['date ', 'close']]
#       8 stocks_data.head()
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/base.py:5859, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['date '] not in index"

# %%
stocks_data.date = pd.to_datetime(stocks_data.date, format="%Y-%m-%d")
stocks_data.set_index('date', inplace=True)
stocks_data.plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#normalization technique
def normalization(series):
    return series/series[0]

stocks_data_normalized = stocks_data.apply(normalization, axis=0)

print(stocks_data_normalized.head())
stocks_data_normalized.plot(figsize=(15,7))
# Out:
#                 goog   fb amzn aapl meli
# date
# 2023-03-13  1.000000  NaN  NaN  NaN  NaN
# 2023-03-14  1.028257  NaN  NaN  NaN  NaN
# 2023-03-15  1.053349  NaN  NaN  NaN  NaN
# 2023-03-16  1.102662  NaN  NaN  NaN  NaN
# 2023-03-17  1.117827  NaN  NaN  NaN  NaN
# <AxesSubplot:xlabel='date'>
